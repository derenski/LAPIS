# %% [markdown]
# # The LAPIS (Low-rank Approximation via Partially Imputed Svd) Algorithm

# %%
library(ggplot2)
library(tidyverse)
library(LaplacesDemon)
library(glmnet)
library(foreach)
library(doParallel)
library(quadprog)
library(openxlsx)
library(plyr)
library(dplyr)
library(cubelyr)

max_available_clusters <- detectCores()-1
  
desired_clusters <- 4
  
cl <- makeCluster(min(c(max_available_clusters, desired_clusters)))

registerDoParallel(cl)
 
source('causal_inference_methods_code.R')


mse_and_se_of_mse <- function(error_mat){
  
  squared_errors <- error_mat
  
  the_mse <- mean(squared_errors)
  
  se_mse <- sqrt((sd(squared_errors)^2)/prod(dim(squared_errors)))
  
  final_stuff <- c(the_mse, se_mse)
  
  names(final_stuff) <- c("mse", "se_mse")
  
  return(final_stuff)
  
}



params <- read.xlsx("parameters_and_descriptions.xlsx", sheet = "parameter_data", rowNames=T)


quiet <- function(x) { 
  sink(tempfile()) 
  on.exit(sink()) 
  invisible(force(x)) 
} 

makeFilename <- function(directory, fileName){
    
    paste(directory, fileName, sep='/')
}                            



options(dplyr.summarise.inform = FALSE)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘LaplacesDemon’
#
#
# The following object is masked from ‘package:purrr’:
#
#     partial
#
#
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# Loaded glmnet 3.0-2
#
#
#
# Attaching package: ‘foreach’
#
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# ------------------------------------------------------------------------------
#
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
#
# ------------------------------------------------------------------------------
#
#
# Attaching package: ‘plyr’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following object is masked from ‘package:purrr’:
#
#     compact

# %%
methodNames <- c('DID','SC', 'SDID', "MC-NNM", 'LAPIS', 'ORACLE')

# %%
params <- read.xlsx("parameters_and_descriptions.xlsx", sheet = "parameter_data", rowNames=T)

# %%
set.seed(3729)

number_of_L <- as.numeric(params["number_of_Ls", ])

draws_per_L <- as.numeric(params["draws_per_L", ])

N <- as.numeric(params["N", ])

N0 <- N-as.numeric(params["N1", ])

Time <- as.numeric(params["Time", ])

Time0 <- as.numeric(Time)-as.numeric(params["Time1", ])

R <- as.numeric(params["R", ])

rho_parameter <- as.numeric(params['rho_parameter', ])

tau <- as.numeric(params['tau', ])

sigma_squared <- as.numeric(params['sigma_squared', ])

penalized <- as.logical(as.numeric(params['penalized', ]))

balanced <- as.logical(params['balanced', ])

min_iter <- as.numeric(params['min_iter', ])

max_iter <- as.numeric(params['max_iter', ])

tolerance <- as.numeric(params['tolerance', ])

error = params['error', ]

df <- as.numeric(params['df', ])

rank_estimation_method <- params['rank_estimation_method', ]

L_scaling <- as.numeric(params['L_scaling', ])

arg_max <- as.numeric(params['arg_max', ])
  
y_max <- as.numeric(params['y_max', ])
  
halfway_time <- as.numeric(params['halfway_time', ])

cutoff <- as.numeric(params['cutoff', ])

design <- params['design', ]

lag_structure <- params['lag_structure', ]

average_treatment_length <- min(as.numeric(params['average_treatment_length', ]), Time-Time0)

max_lag <- as.numeric(params['max_lag', ])

treatment_function <- list_of_functions[[params['treatment_effect_function', ]]]

# %% [markdown]
# # Simulations
#
# ## Parameters
#
# - Number of Ls: `r number_of_L`
#
# - Draws per L: `r draws_per_L`
#
# - Number of Units: `r N`
#
# - Number of Control Units: `r N0`
#
# - Number of Times: `r Time`
#
# - Number of pre-treatment Times: `r Time0`
#
# - Rank of L: `r R`
#
# - Autocorrelation Parameter: `r rho_parameter`
#
# - True Effect Size for Constant Effect: `r tau`
#
# - Error Type: `r error`
#
# - Error Variance (if Gaussian error): `r sigma_squared`
#
# - Degrees of freedom (if t-error): `r df`
#
# - balanced: `r balanced`
#
# - Penalized: `r penalized`
#
# - Rank Estimation Method: `r rank_estimation_method`
#
# - Scaling for $L$: `r L_scaling`
#
# - Treatment Effect Type: `r params$treatment_effect_function`
#
# - Treatment Design: `r design`
#
# - Lag Structure (if using staggered adoption structure): `r lag_structure`
#
# - Average Treatment Length (if using staggered adoption structure, with random adoption): `r average_treatment_length`
#
# - Maximum lag: `r max_lag`

# %% [markdown]
# # LAPIS vs Competitors, Fixed Parameters

# %%
msesFixedParameterData <- array(NA, dim=c(length(methodNames), draws_per_L, number_of_L ),
                   dimnames=c(list(Method=methodNames), list(Iteration=1:draws_per_L), list(L_number=1:number_of_L)))

if (design=="staggered_adoption"){ 
  
  if(lag_structure == "random"){
    
    ones_we_make <- c(rep(0, N0), pmin(rpois(N-N0, 
                                            lambda=average_treatment_length-1)+1, 
                                      min(max_lag*(N-N0), .8*Time)))
    
  }else if (lag_structure=="constant"){ ## Does not control T-T0
    
    ones_we_make <- c(rep(0, N0), pmin(max_lag*seq(1, (N-N0)), floor(.8*Time)))
    
  }

}else if (design=="simultaneous_adoption"){
  
  ones_we_make <- c(rep(0, N0), rep(Time-Time0, N-N0))
  
}

W <- W_maker(N=N, Time=Time, ones_per_row = ones_we_make)

tau_matrix <- t(apply(W, MARGIN=1, FUN=treated_matrix_creator, 
                      f_of_t=treatment_function, arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff))

treated_units <- as.numeric(which(apply(W, MARGIN=1, FUN = function(x) any(x==1))))
  
treatment_times <- as.numeric(which(apply(W, MARGIN=2, FUN = function(x) any(x==1))))

delta_t <- treatment_function(treatment_times-(min(treatment_times)-1),
                              arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff, value=tau)

autocorrelation_matrix <- make_rho_mat(rho=rho_parameter, p=dim(W)[2])

sig_to_noise_ratios <- c()

for (i in 1:number_of_L){
  
  if (balanced){
    
    U_vec <- rexp(n=N*R, rate=1)

    V_vec <- rexp(n=Time*R, rate=1)
  
    U <- matrix(U_vec, nrow=N, ncol=R, byrow=T)

    V <- matrix(V_vec, nrow=Time, ncol=R, byrow=T)
  
  }else{
    
    U <- matrix(NA, nrow=N, ncol=R, byrow=T)

    V <- matrix(NA, nrow=Time, ncol=R, byrow=T)
    
    for (row_unit in 1:N){
      
      U[row_unit,] <- rpois(n=R, lambda=sqrt(row_unit/N))
      
    } 
    
    for (row_time in 1:Time){
      
      V[row_time,] <- rpois(n=R, lambda=sqrt(row_time/Time))
      
    }
    
  }

  L <- L_scaling*(U %*% t(V))
  
  for (j in 1:draws_per_L){
      
    startTime <- Sys.time()
    
    if (error == 'gaussian'){
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W, distribution='gaussian',
                 scalar_sigma=sqrt(sigma_squared))
      
    } else if (error == 't'){
    
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='t', scalar_sigma=sqrt(sigma_squared))
    
    } else if (error == 'poisson'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='poisson', scalar_sigma=sqrt(sigma_squared))
      
    } else if (error == 'scaled_gamma'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='scaled_gamma', scalar_sigma=sqrt(sigma_squared))
      
    }else if (error == 'exponential'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='exponential', scalar_sigma=sqrt(sigma_squared))

    }
    
    #estimated_rank <- rank_estimator(Y, W, num_iter=100, K=5, 
    #                      lambda_grid=c(0, 10^seq(-20, 0, 2)), 
    #                      method="threshold")
    
    #Y_0_LAPIS <- LAPIS(Y, rank_threshold=estimated_rank,
    #                                    min_iter=1, max_iter=max_iter,
    #                                    tolerance=tolerance, W=W)
    
    
    if (N-N0 > 1){
    
    treatment_subjects_averaged <- colMeans(Y[1:dim(Y)[1] > N0,])
    
    W_averaged <- colMeans(W[1:dim(W)[1] > N0,])
    
    new_Y <- rbind(Y[1:dim(Y)[1] <= N0,], treatment_subjects_averaged)
    
    new_W <- rbind(W[1:dim(Y)[1] <= N0,], W_averaged)
    
    } else {
    
      new_Y <- Y
    
      new_W <- W
      
      
    }

      
    
    tau_estimate_did <- DID(Y=Y, W=W)
    
    tau_estimate_sc <- synth_cont(Y=Y, W=W)
    
    tau_estimate_sdid <- SDID_general(Y=Y, W=W,
                 iterations_for_coord_desc=100)
    
    mc_nnm_info <- matrix_completion_causal(Y=Y, W=W, num_iter=1000, K=5, 
                            lambda_grid=c(10^seq(-4,2,1), seq(2,5,1)),
                            tol=1e-04)
    
    L_mc_nnm <- mc_nnm_info$L_hat
    
    tau_estimate_mc_nnm <- treat.estimator(Y=Y, L.hat=L_mc_nnm, W=W)
    
    estFactors <- rankMatrix(mc_nnm_info$L_hat)[1]  
    
    lapis_info <- LAPIS_with_rank_estimation(Y=Y, 
                           W=W, initial_rank=rankMatrix(mc_nnm_info$L_hat)[1],
                           tolerance=tolerance, 
                           min_iter=min_iter, max_iter=max_iter,   
                           mu_grid=NULL, warm_start=F, method = 'explicit_tau')
      
      
    tau_estimate_lapis <- treat.estimator(Y, lapis_info, W)
    
    tau_estimate_oracle <- treat.estimator(Y=Y, L.hat=L, W=W)

    msesFixedParameterData['DID', j, i] <- mean(abs(tau_estimate_did-delta_t)^2)
    
    msesFixedParameterData['SC', j, i] <- mean(abs(tau_estimate_sc-delta_t)^2)
    
    msesFixedParameterData['MC-NNM', j, i] <- mean(abs(tau_estimate_mc_nnm-delta_t)^2)
    
    msesFixedParameterData['SDID', j, i] <- mean(abs(tau_estimate_sdid-delta_t)^2)
    
    msesFixedParameterData['LAPIS', j, i] <- mean(abs(tau_estimate_lapis-delta_t)^2)
    
    msesFixedParameterData['ORACLE', j, i] <- mean(abs(tau_estimate_oracle-delta_t)^2)
      
    outMessage <- paste('Iteration: ', j, sep='')
      
    print(outMessage)
      
    endTime <- Sys.time()
      
    print(difftime(endTime, startTime, 'mins'))

  }


}


effect_plot <- (ggplot(NULL, aes(x=1:length(delta_t), y=delta_t)) 
                + geom_point() + theme_bw() + xlab("Time") + ylab("Treatment Effect")
                +ggtitle("True Treatment Effect Over Time"))
# Out:
# [1] "Iteration: 1"
# Time difference of 21.98999 secs
# [1] "Iteration: 2"
# Time difference of 17.10269 secs
# [1] "Iteration: 3"
# Time difference of 16.42618 secs
# [1] "Iteration: 4"
# Time difference of 11.38602 secs
# [1] "Iteration: 5"
# Time difference of 15.9274 secs
# [1] "Iteration: 6"
# Time difference of 17.24381 secs
# [1] "Iteration: 7"
# Time difference of 16.45722 secs
# [1] "Iteration: 8"
# Time difference of 19.87103 secs
# [1] "Iteration: 9"
# Time difference of 18.19786 secs
# [1] "Iteration: 10"
# Time difference of 22.4145 secs
# [1] "Iteration: 11"
# Time difference of 18.17693 secs
# [1] "Iteration: 12"
# Time difference of 19.86786 secs
# [1] "Iteration: 13"
# Time difference of 21.6019 secs
# [1] "Iteration: 14"
# Time difference of 15.95346 secs
# [1] "Iteration: 15"
# Time difference of 13.16158 secs
# [1] "Iteration: 16"
# Time difference of 16.29087 secs
# [1] "Iteration: 17"
# Time difference of 19.29152 secs
# [1] "Iteration: 18"
# Time difference of 20.15655 secs
# [1] "Iteration: 19"
# Time difference of 15.82885 secs
# [1] "Iteration: 20"
# Time difference of 21.18076 secs
# [1] "Iteration: 21"
# Time difference of 18.52004 secs
# [1] "Iteration: 22"
# Time difference of 16.47832 secs
# [1] "Iteration: 23"
# Time difference of 14.61315 secs
# [1] "Iteration: 24"
# Time difference of 15.50512 secs
# [1] "Iteration: 25"
# Time difference of 11.15907 secs
# [1] "Iteration: 26"
# Time difference of 16.69373 secs
# [1] "Iteration: 27"
# Time difference of 19.99731 secs
# [1] "Iteration: 28"
# Time difference of 18.911 secs
# [1] "Iteration: 29"
# Time difference of 14.49076 secs
# [1] "Iteration: 30"
# Time difference of 15.73352 secs
# [1] "Iteration: 31"
# Time difference of 11.76325 secs
# [1] "Iteration: 32"
# Time difference of 16.41175 secs
# [1] "Iteration: 33"
# Time difference of 18.08483 secs
# [1] "Iteration: 34"
# Time difference of 17.39599 secs
# [1] "Iteration: 35"
# Time difference of 14.54187 secs
# [1] "Iteration: 36"
# Time difference of 16.47116 secs
# [1] "Iteration: 37"
# Time difference of 18.82109 secs
# [1] "Iteration: 38"
# Time difference of 15.29845 secs
# [1] "Iteration: 39"
# Time difference of 18.65604 secs
# [1] "Iteration: 40"
# Time difference of 21.80428 secs
# [1] "Iteration: 41"
# Time difference of 14.14824 secs
# [1] "Iteration: 42"
# Time difference of 20.07557 secs
# [1] "Iteration: 43"
# Time difference of 20.71749 secs
# [1] "Iteration: 44"
# Time difference of 18.71466 secs
# [1] "Iteration: 45"
# Time difference of 16.85584 secs
# [1] "Iteration: 46"
# Time difference of 17.93607 secs
# [1] "Iteration: 47"
# Time difference of 12.73389 secs
# [1] "Iteration: 48"
# Time difference of 19.19531 secs
# [1] "Iteration: 49"
# Time difference of 19.19689 secs
# [1] "Iteration: 50"
# Time difference of 12.80842 secs

# %% [markdown]
# ## Results

# %%
meltedFixedParameterData <- as_tibble(as.tbl_cube(msesFixedParameterData, met='MSE'))

                                          
meltedFixedParameterData$Method <- factor(meltedFixedParameterData$Method, levels=methodNames)

fixed_parameter_error_frame <- meltedFixedParameterData %>% filter(Method !='DID')                                          
                                          
tableForPresenting <- (fixed_parameter_error_frame %>% group_by(Method) %>% dplyr::summarize(RMSE = round(mean(sqrt(MSE)), 3),
                        SE=round(sd(sqrt(MSE), na.rm=T)/sqrt(n()), 3),
            `RMSE (SE)` = paste(RMSE
                    ,' (', SE, ')',
            sep='')))[, c('Method', 'RMSE (SE)')]
                                          

tableForPresenting <- knitr::kable(tableForPresenting, 'latex')

# %% [markdown]
# # Matrix Bias vs Reduction in Variance due to Averaging
#
# For more general designs of $W$ (like the block design scheme considered here) we allow a block in the bottom right hand corner of $W$ to be non-zero. When implementing LAPIS, we have two competing effects on estimation:
#
# - The bias that's introduced by making more of the $Y_{ij}$s zero.
#
# - The help we get with estimating $\tau$ by being able to average over cells (because we asmeane $tau$) is the same for all units and times.

# %% [markdown]
# It would appear that accurracy increases for estimating $\tau$ to a point, and then decreases when the bias introduced by replacement of cells with $0$ in $Y$ becomes too great.
#
# # Influence of $N_{0}/N$ on Performance

# %%
### WITH N0/N
## Chunk 18

### floor((c(5, seq(10, 90, 10), 98)/100)*N)

all_N0s <- floor(c(.1, .3, .5, .7, .9)*N)

msesN0Data <- array(NA, dim=c(length(methodNames), draws_per_L, length(all_N0s) ),
                   dimnames=c(list(Method=methodNames), list(Iteration=1:draws_per_L), list(N0=all_N0s )))

for (this_N0 in all_N0s){ 
    
  N0ForIndex <- as.character(this_N0 )
  
  set.seed(3729)
  
  if (design=="staggered_adoption"){ 
  
  if(lag_structure == "random"){
    
    ones_we_make <- c(rep(0, this_N0), pmin(rpois(N-this_N0, 
                                            lambda=average_treatment_length-1)+1, 
                                      min(max_lag*(N-this_N0), .8*Time)))
    
  }else if (lag_structure=="constant"){ ## Does not control T-T0
    
    ones_we_make <- c(rep(0, this_N0), pmin(max_lag*seq(1, (N-this_N0)), floor(.8*Time)))
    
  }

}else if (design=="simultaneous_adoption"){
  
  ones_we_make <- c(rep(0, this_N0), rep(Time-Time0, N-this_N0))
  
}
  
  W <- W_maker(N=N, Time=Time, ones_per_row = ones_we_make)

  tau_matrix <- t(apply(W, MARGIN=1, FUN=treated_matrix_creator, 
                      f_of_t=treatment_function, arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff, 
                      value=tau))

  treated_units <- as.numeric(which(apply(W, MARGIN=1, FUN = function(x) any(x==1))))
  
  treatment_times <- as.numeric(which(apply(W, MARGIN=2, FUN = function(x) any(x==1))))

  delta_t <- treatment_function(treatment_times-(min(treatment_times)-1),
                              arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff, value=tau)
  
  autocorrelation_matrix <- make_rho_mat(rho=rho_parameter, p=dim(W)[2])
 
  for (i in 1:number_of_L){
  
 # set.seed(3729)

  if (balanced){
    
    U_vec <- rexp(n=N*R, rate=1)

    V_vec <- rexp(n=Time*R, rate=1)
  
    U <- matrix(U_vec, nrow=N, ncol=R, byrow=T)

    V <- matrix(V_vec, nrow=Time, ncol=R, byrow=T)
  
  }else{
    
    U <- matrix(NA, nrow=N, ncol=R, byrow=T)

    V <- matrix(NA, nrow=Time, ncol=R, byrow=T)
    
    for (row_unit in 1:N){
      
      U[row_unit,] <- rpois(n=R, lambda=sqrt(row_unit/N))
      
    } 
    
    for (row_time in 1:Time){
      
      V[row_time,] <- rpois(n=R, lambda=sqrt(row_time/Time))
      
    }
    
  }

  L <- L_scaling*(U %*% t(V))
  
  for (j in 1:draws_per_L){
      
      startTime <- Sys.time()
    
    if (error == 'gaussian'){
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W, distribution='gaussian',
                 scalar_sigma=sqrt(sigma_squared))
      
    } else if (error == 't'){
    
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='t', scalar_sigma=sqrt(sigma_squared))
    
    } else if (error == 'poisson'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='poisson', scalar_sigma=sqrt(sigma_squared))
      
    } else if (error == 'scaled_gamma'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='scaled_gamma', scalar_sigma=sqrt(sigma_squared))
      
    }else if (error == 'exponential'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='exponential', scalar_sigma=sqrt(sigma_squared))

    }
    
    #estimated_rank <- rank_estimator(Y, W, num_iter=100, K=5, 
    #                      lambda_grid=c(0, 10^seq(-20, 0, 2)), 
    #                      method="threshold")
    
    #Y_0_LAPIS <- LAPIS(Y, rank_threshold=estimated_rank,
    #                                    min_iter=1, max_iter=max_iter,
    #                                    tolerance=tolerance, W=W)
    
    
    if (N-this_N0 > 1){
    
    treatment_subjects_averaged <- colMeans(Y[1:dim(Y)[1] > this_N0,])
    
    W_averaged <- colMeans(W[1:dim(W)[1] > this_N0,])
    
    new_Y <- rbind(Y[1:dim(Y)[1] <= this_N0,], treatment_subjects_averaged)
    
    new_W <- rbind(W[1:dim(Y)[1] <= this_N0,], W_averaged)
    
    } else {
    
      new_Y <- Y
    
      new_W <- W
      
      
    }
    
    tau_estimate_did <- DID(Y=Y, W=W)
    
    tau_estimate_sc <- synth_cont(Y=Y, W=W)           

    tau_estimate_sdid <- SDID_general(Y=Y, W=W,
                 iterations_for_coord_desc=100)
    
    mc_nnm_info <- matrix_completion_causal(Y=Y, W=W, num_iter=1000, K=5, 
                            lambda_grid=c(10^seq(-4,2,1), seq(2,5,1)),
                            tol=1e-04)
    
    L_mc_nnm <- mc_nnm_info$L_hat
    
    tau_estimate_mc_nnm <- treat.estimator(Y=Y, L.hat=L_mc_nnm, W=W)
      
      
    estFactors <- rankMatrix(mc_nnm_info$L_hat)[1]  
      
    lapis_info <- LAPIS_with_rank_estimation(Y=Y, 
                           W=W, initial_rank=rankMatrix(mc_nnm_info$L_hat)[1],
                           tolerance=tolerance, 
                           min_iter=min_iter, max_iter=max_iter,   
                           mu_grid=NULL, warm_start=F, method = 'explicit_tau')
      
      
    tau_estimate_lapis <- treat.estimator(Y, lapis_info, W)
    
    tau_estimate_oracle <- treat.estimator(Y=Y, L.hat=L, W=W)
    

    msesN0Data['DID', j, N0ForIndex] <- mean(abs(tau_estimate_did-delta_t)^2)
    
    msesN0Data['SC', j, N0ForIndex] <- mean(abs(tau_estimate_sc-delta_t)^2)
    
    msesN0Data['MC-NNM', j, N0ForIndex] <- mean(abs(tau_estimate_mc_nnm-delta_t)^2)
    
    msesN0Data['SDID', j, N0ForIndex] <- mean(abs(tau_estimate_sdid-delta_t)^2)
    
    msesN0Data['LAPIS', j, N0ForIndex] <- mean(abs(tau_estimate_lapis-delta_t)^2)
    
    msesN0Data['ORACLE', j, N0ForIndex] <- mean(abs(tau_estimate_oracle-delta_t)^2)
      
    endTime <- Sys.time()
      
    outMessage <- paste('N0/N: ', this_N0/N, '; Iteration: ', j, sep='')
      
    print(outMessage)
      
    print(difftime(endTime, startTime, 'mins'))

  }


}

}
  
meltedN0Data <- as_tibble(as.tbl_cube(msesN0Data, met='MSE'))

meltedN0Data$Method <- factor(meltedN0Data$Method, levels=methodNames)                                            
                                            
meltedN0Data  <- meltedN0Data  %>% filter(Method !='DID') 
 
aggN0Data <- meltedN0Data %>% group_by(Method, N0) %>% dplyr::summarize(RMSE = mean(sqrt(MSE)),
                                                                SE = sd(sqrt(MSE))/sqrt(n()))

p_mse_vs_N0 <- (ggplot(aggN0Data, aes(x=N0/N, y=RMSE, col=Method)) + geom_line(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of N0/N") 
                +xlab("N0/N") + ylab('RMSE'))
                                            
p_mse_vs_N0_uncertainty <- (ggplot(meltedN0Data, aes(x=N0/N, y=sqrt(MSE), col=Method)) + geom_smooth(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of N0/N") 
                +xlab("N0/N") + ylab('RMSE'))
# Out:
# [1] "N0/N: 0.1; Iteration: 1"
# Time difference of 47.83846 secs
# [1] "N0/N: 0.1; Iteration: 2"
# Time difference of 47.6984 secs
# [1] "N0/N: 0.1; Iteration: 3"
# Time difference of 37.75939 secs
# [1] "N0/N: 0.1; Iteration: 4"
# Time difference of 49.44364 secs
# [1] "N0/N: 0.1; Iteration: 5"
# Time difference of 47.53196 secs
# [1] "N0/N: 0.1; Iteration: 6"
# Time difference of 46.7305 secs
# [1] "N0/N: 0.1; Iteration: 7"
# Time difference of 37.38247 secs
# [1] "N0/N: 0.1; Iteration: 8"
# Time difference of 36.10643 secs
# [1] "N0/N: 0.1; Iteration: 9"
# Time difference of 41.2481 secs
# [1] "N0/N: 0.1; Iteration: 10"
# Time difference of 40.60808 secs
# [1] "N0/N: 0.1; Iteration: 11"
# Time difference of 52.15859 secs
# [1] "N0/N: 0.1; Iteration: 12"
# Time difference of 37.36403 secs
# [1] "N0/N: 0.1; Iteration: 13"
# Time difference of 36.68612 secs
# [1] "N0/N: 0.1; Iteration: 14"
# Time difference of 49.17513 secs
# [1] "N0/N: 0.1; Iteration: 15"
# Time difference of 49.26542 secs
# [1] "N0/N: 0.1; Iteration: 16"
# Time difference of 39.06257 secs
# [1] "N0/N: 0.1; Iteration: 17"
# Time difference of 36.38528 secs
# [1] "N0/N: 0.1; Iteration: 18"
# Time difference of 49.54574 secs
# [1] "N0/N: 0.1; Iteration: 19"
# Time difference of 49.9179 secs
# [1] "N0/N: 0.1; Iteration: 20"
# Time difference of 47.30588 secs
# [1] "N0/N: 0.1; Iteration: 21"
# Time difference of 38.42787 secs
# [1] "N0/N: 0.1; Iteration: 22"
# Time difference of 37.66807 secs
# [1] "N0/N: 0.1; Iteration: 23"
# Time difference of 51.0267 secs
# [1] "N0/N: 0.1; Iteration: 24"
# Time difference of 51.57563 secs
# [1] "N0/N: 0.1; Iteration: 25"
# Time difference of 51.23563 secs
# [1] "N0/N: 0.1; Iteration: 26"
# Time difference of 51.65747 secs
# [1] "N0/N: 0.1; Iteration: 27"
# Time difference of 50.56009 secs
# [1] "N0/N: 0.1; Iteration: 28"
# Time difference of 50.34417 secs
# [1] "N0/N: 0.1; Iteration: 29"
# Time difference of 51.05921 secs
# [1] "N0/N: 0.1; Iteration: 30"
# Time difference of 50.1456 secs
# [1] "N0/N: 0.1; Iteration: 31"
# Time difference of 37.96683 secs
# [1] "N0/N: 0.1; Iteration: 32"
# Time difference of 49.22254 secs
# [1] "N0/N: 0.1; Iteration: 33"
# Time difference of 38.55962 secs
# [1] "N0/N: 0.1; Iteration: 34"
# Time difference of 49.41838 secs
# [1] "N0/N: 0.1; Iteration: 35"
# Time difference of 46.55708 secs
# [1] "N0/N: 0.1; Iteration: 36"
# Time difference of 50.2427 secs
# [1] "N0/N: 0.1; Iteration: 37"
# Time difference of 47.53472 secs
# [1] "N0/N: 0.1; Iteration: 38"
# Time difference of 40.42228 secs
# [1] "N0/N: 0.1; Iteration: 39"
# Time difference of 35.70617 secs
# [1] "N0/N: 0.1; Iteration: 40"
# Time difference of 48.95837 secs
# [1] "N0/N: 0.1; Iteration: 41"
# Time difference of 38.47755 secs
# [1] "N0/N: 0.1; Iteration: 42"
# Time difference of 52.36437 secs
# [1] "N0/N: 0.1; Iteration: 43"
# Time difference of 49.68333 secs
# [1] "N0/N: 0.1; Iteration: 44"
# Time difference of 45.5257 secs
# [1] "N0/N: 0.1; Iteration: 45"
# Time difference of 46.44423 secs
# [1] "N0/N: 0.1; Iteration: 46"
# Time difference of 46.3463 secs
# [1] "N0/N: 0.1; Iteration: 47"
# Time difference of 47.54044 secs
# [1] "N0/N: 0.1; Iteration: 48"
# Time difference of 38.33334 secs
# [1] "N0/N: 0.1; Iteration: 49"
# Time difference of 47.09636 secs
# [1] "N0/N: 0.1; Iteration: 50"
# Time difference of 34.98281 secs
# [1] "N0/N: 0.3; Iteration: 1"
# Time difference of 26.13759 secs
# [1] "N0/N: 0.3; Iteration: 2"
# Time difference of 27.01111 secs
# [1] "N0/N: 0.3; Iteration: 3"
# Time difference of 29.9794 secs
# [1] "N0/N: 0.3; Iteration: 4"
# Time difference of 27.84564 secs
# [1] "N0/N: 0.3; Iteration: 5"
# Time difference of 26.63925 secs
# [1] "N0/N: 0.3; Iteration: 6"
# Time difference of 28.56062 secs
# [1] "N0/N: 0.3; Iteration: 7"
# Time difference of 30.43687 secs
# [1] "N0/N: 0.3; Iteration: 8"
# Time difference of 28.38842 secs
# [1] "N0/N: 0.3; Iteration: 9"
# Time difference of 28.66771 secs
# [1] "N0/N: 0.3; Iteration: 10"
# Time difference of 30.24559 secs
# [1] "N0/N: 0.3; Iteration: 11"
# Time difference of 31.80726 secs
# [1] "N0/N: 0.3; Iteration: 12"
# Time difference of 27.88234 secs
# [1] "N0/N: 0.3; Iteration: 13"
# Time difference of 28.36162 secs
# [1] "N0/N: 0.3; Iteration: 14"
# Time difference of 29.1708 secs
# [1] "N0/N: 0.3; Iteration: 15"
# Time difference of 27.73182 secs
# [1] "N0/N: 0.3; Iteration: 16"
# Time difference of 29.96149 secs
# [1] "N0/N: 0.3; Iteration: 17"
# Time difference of 29.10225 secs
# [1] "N0/N: 0.3; Iteration: 18"
# Time difference of 28.20092 secs
# [1] "N0/N: 0.3; Iteration: 19"
# Time difference of 29.91844 secs
# [1] "N0/N: 0.3; Iteration: 20"
# Time difference of 28.18953 secs
# [1] "N0/N: 0.3; Iteration: 21"
# Time difference of 26.71232 secs
# [1] "N0/N: 0.3; Iteration: 22"
# Time difference of 27.2534 secs
# [1] "N0/N: 0.3; Iteration: 23"
# Time difference of 29.72004 secs
# [1] "N0/N: 0.3; Iteration: 24"
# Time difference of 27.46437 secs
# [1] "N0/N: 0.3; Iteration: 25"
# Time difference of 27.68936 secs
# [1] "N0/N: 0.3; Iteration: 26"
# Time difference of 27.04662 secs
# [1] "N0/N: 0.3; Iteration: 27"
# Time difference of 27.93671 secs
# [1] "N0/N: 0.3; Iteration: 28"
# Time difference of 30.36365 secs
# [1] "N0/N: 0.3; Iteration: 29"
# Time difference of 31.46762 secs
# [1] "N0/N: 0.3; Iteration: 30"
# Time difference of 28.0855 secs
# [1] "N0/N: 0.3; Iteration: 31"
# Time difference of 29.47892 secs
# [1] "N0/N: 0.3; Iteration: 32"
# Time difference of 28.69708 secs
# [1] "N0/N: 0.3; Iteration: 33"
# Time difference of 27.96585 secs
# [1] "N0/N: 0.3; Iteration: 34"
# Time difference of 28.9365 secs
# [1] "N0/N: 0.3; Iteration: 35"
# Time difference of 28.1285 secs
# [1] "N0/N: 0.3; Iteration: 36"
# Time difference of 27.26689 secs
# [1] "N0/N: 0.3; Iteration: 37"
# Time difference of 28.01763 secs
# [1] "N0/N: 0.3; Iteration: 38"
# Time difference of 27.65775 secs
# [1] "N0/N: 0.3; Iteration: 39"
# Time difference of 28.43825 secs
# [1] "N0/N: 0.3; Iteration: 40"
# Time difference of 27.40913 secs
# [1] "N0/N: 0.3; Iteration: 41"
# Time difference of 28.04228 secs
# [1] "N0/N: 0.3; Iteration: 42"
# Time difference of 26.63781 secs
# [1] "N0/N: 0.3; Iteration: 43"
# Time difference of 29.68521 secs
# [1] "N0/N: 0.3; Iteration: 44"
# Time difference of 28.90917 secs
# [1] "N0/N: 0.3; Iteration: 45"
# Time difference of 26.43347 secs
# [1] "N0/N: 0.3; Iteration: 46"
# Time difference of 28.11779 secs
# [1] "N0/N: 0.3; Iteration: 47"
# Time difference of 29.52903 secs
# [1] "N0/N: 0.3; Iteration: 48"
# Time difference of 27.22299 secs
# [1] "N0/N: 0.3; Iteration: 49"
# Time difference of 28.42632 secs
# [1] "N0/N: 0.3; Iteration: 50"
# Time difference of 27.31268 secs
# [1] "N0/N: 0.5; Iteration: 1"
# Time difference of 26.61752 secs
# [1] "N0/N: 0.5; Iteration: 2"
# Time difference of 26.25015 secs
# [1] "N0/N: 0.5; Iteration: 3"
# Time difference of 25.56753 secs
# [1] "N0/N: 0.5; Iteration: 4"
# Time difference of 25.01406 secs
# [1] "N0/N: 0.5; Iteration: 5"
# Time difference of 25.29672 secs
# [1] "N0/N: 0.5; Iteration: 6"
# Time difference of 25.47637 secs
# [1] "N0/N: 0.5; Iteration: 7"
# Time difference of 25.1024 secs
# [1] "N0/N: 0.5; Iteration: 8"
# Time difference of 26.1476 secs
# [1] "N0/N: 0.5; Iteration: 9"
# Time difference of 25.7404 secs
# [1] "N0/N: 0.5; Iteration: 10"
# Time difference of 26.41646 secs
# [1] "N0/N: 0.5; Iteration: 11"
# Time difference of 24.92214 secs
# [1] "N0/N: 0.5; Iteration: 12"
# Time difference of 26.9287 secs
# [1] "N0/N: 0.5; Iteration: 13"
# Time difference of 26.70408 secs
# [1] "N0/N: 0.5; Iteration: 14"
# Time difference of 26.38791 secs
# [1] "N0/N: 0.5; Iteration: 15"
# Time difference of 25.76931 secs
# [1] "N0/N: 0.5; Iteration: 16"
# Time difference of 27.15535 secs
# [1] "N0/N: 0.5; Iteration: 17"
# Time difference of 27.38021 secs
# [1] "N0/N: 0.5; Iteration: 18"
# Time difference of 24.39702 secs
# [1] "N0/N: 0.5; Iteration: 19"
# Time difference of 25.99002 secs
# [1] "N0/N: 0.5; Iteration: 20"
# Time difference of 26.79353 secs
# [1] "N0/N: 0.5; Iteration: 21"
# Time difference of 26.95431 secs
# [1] "N0/N: 0.5; Iteration: 22"
# Time difference of 26.29575 secs
# [1] "N0/N: 0.5; Iteration: 23"
# Time difference of 25.33392 secs
# [1] "N0/N: 0.5; Iteration: 24"
# Time difference of 26.77689 secs
# [1] "N0/N: 0.5; Iteration: 25"
# Time difference of 26.12128 secs
# [1] "N0/N: 0.5; Iteration: 26"
# Time difference of 27.15272 secs
# [1] "N0/N: 0.5; Iteration: 27"
# Time difference of 25.64349 secs
# [1] "N0/N: 0.5; Iteration: 28"
# Time difference of 25.58844 secs
# [1] "N0/N: 0.5; Iteration: 29"
# Time difference of 26.11771 secs
# [1] "N0/N: 0.5; Iteration: 30"
# Time difference of 25.94787 secs
# [1] "N0/N: 0.5; Iteration: 31"
# Time difference of 25.34 secs
# [1] "N0/N: 0.5; Iteration: 32"
# Time difference of 25.58076 secs
# [1] "N0/N: 0.5; Iteration: 33"
# Time difference of 25.48101 secs
# [1] "N0/N: 0.5; Iteration: 34"
# Time difference of 27.19452 secs
# [1] "N0/N: 0.5; Iteration: 35"
# Time difference of 26.28717 secs
# [1] "N0/N: 0.5; Iteration: 36"
# Time difference of 25.69428 secs
# [1] "N0/N: 0.5; Iteration: 37"
# Time difference of 26.46461 secs
# [1] "N0/N: 0.5; Iteration: 38"
# Time difference of 25.06933 secs
# [1] "N0/N: 0.5; Iteration: 39"
# Time difference of 26.80027 secs
# [1] "N0/N: 0.5; Iteration: 40"
# Time difference of 25.75032 secs
# [1] "N0/N: 0.5; Iteration: 41"
# Time difference of 26.56379 secs
# [1] "N0/N: 0.5; Iteration: 42"
# Time difference of 25.72099 secs
# [1] "N0/N: 0.5; Iteration: 43"
# Time difference of 24.81649 secs
# [1] "N0/N: 0.5; Iteration: 44"
# Time difference of 26.75279 secs
# [1] "N0/N: 0.5; Iteration: 45"
# Time difference of 26.4914 secs
# [1] "N0/N: 0.5; Iteration: 46"
# Time difference of 25.11681 secs
# [1] "N0/N: 0.5; Iteration: 47"
# Time difference of 26.91231 secs
# [1] "N0/N: 0.5; Iteration: 48"
# Time difference of 24.53913 secs
# [1] "N0/N: 0.5; Iteration: 49"
# Time difference of 26.14322 secs
# [1] "N0/N: 0.5; Iteration: 50"
# Time difference of 24.77775 secs
# [1] "N0/N: 0.7; Iteration: 1"
# Time difference of 21.35558 secs
# [1] "N0/N: 0.7; Iteration: 2"
# Time difference of 23.62205 secs
# [1] "N0/N: 0.7; Iteration: 3"
# Time difference of 21.75594 secs
# [1] "N0/N: 0.7; Iteration: 4"
# Time difference of 22.14282 secs
# [1] "N0/N: 0.7; Iteration: 5"
# Time difference of 21.05829 secs
# [1] "N0/N: 0.7; Iteration: 6"
# Time difference of 21.9026 secs
# [1] "N0/N: 0.7; Iteration: 7"
# Time difference of 22.93207 secs
# [1] "N0/N: 0.7; Iteration: 8"
# Time difference of 23.52135 secs
# [1] "N0/N: 0.7; Iteration: 9"
# Time difference of 22.70051 secs
# [1] "N0/N: 0.7; Iteration: 10"
# Time difference of 23.51661 secs
# [1] "N0/N: 0.7; Iteration: 11"
# Time difference of 22.14345 secs
# [1] "N0/N: 0.7; Iteration: 12"
# Time difference of 20.23601 secs
# [1] "N0/N: 0.7; Iteration: 13"
# Time difference of 22.28781 secs
# [1] "N0/N: 0.7; Iteration: 14"
# Time difference of 22.66213 secs
# [1] "N0/N: 0.7; Iteration: 15"
# Time difference of 23.72772 secs
# [1] "N0/N: 0.7; Iteration: 16"
# Time difference of 23.98298 secs
# [1] "N0/N: 0.7; Iteration: 17"
# Time difference of 22.951 secs
# [1] "N0/N: 0.7; Iteration: 18"
# Time difference of 22.6492 secs
# [1] "N0/N: 0.7; Iteration: 19"
# Time difference of 21.84626 secs
# [1] "N0/N: 0.7; Iteration: 20"
# Time difference of 22.31317 secs
# [1] "N0/N: 0.7; Iteration: 21"
# Time difference of 21.36566 secs
# [1] "N0/N: 0.7; Iteration: 22"
# Time difference of 23.46855 secs
# [1] "N0/N: 0.7; Iteration: 23"
# Time difference of 21.64763 secs
# [1] "N0/N: 0.7; Iteration: 24"
# Time difference of 21.57107 secs
# [1] "N0/N: 0.7; Iteration: 25"
# Time difference of 23.95869 secs
# [1] "N0/N: 0.7; Iteration: 26"
# Time difference of 23.00123 secs
# [1] "N0/N: 0.7; Iteration: 27"
# Time difference of 23.60253 secs
# [1] "N0/N: 0.7; Iteration: 28"
# Time difference of 23.50047 secs
# [1] "N0/N: 0.7; Iteration: 29"
# Time difference of 20.73923 secs
# [1] "N0/N: 0.7; Iteration: 30"
# Time difference of 21.15533 secs
# [1] "N0/N: 0.7; Iteration: 31"
# Time difference of 21.25524 secs
# [1] "N0/N: 0.7; Iteration: 32"
# Time difference of 23.1462 secs
# [1] "N0/N: 0.7; Iteration: 33"
# Time difference of 23.67023 secs
# [1] "N0/N: 0.7; Iteration: 34"
# Time difference of 22.0136 secs
# [1] "N0/N: 0.7; Iteration: 35"
# Time difference of 21.60851 secs
# [1] "N0/N: 0.7; Iteration: 36"
# Time difference of 22.59431 secs
# [1] "N0/N: 0.7; Iteration: 37"
# Time difference of 22.58889 secs
# [1] "N0/N: 0.7; Iteration: 38"
# Time difference of 24.91942 secs
# [1] "N0/N: 0.7; Iteration: 39"
# Time difference of 23.19461 secs
# [1] "N0/N: 0.7; Iteration: 40"
# Time difference of 22.35247 secs
# [1] "N0/N: 0.7; Iteration: 41"
# Time difference of 23.5368 secs
# [1] "N0/N: 0.7; Iteration: 42"
# Time difference of 23.67626 secs
# [1] "N0/N: 0.7; Iteration: 43"
# Time difference of 21.24001 secs
# [1] "N0/N: 0.7; Iteration: 44"
# Time difference of 22.46806 secs
# [1] "N0/N: 0.7; Iteration: 45"
# Time difference of 22.81311 secs
# [1] "N0/N: 0.7; Iteration: 46"
# Time difference of 22.8846 secs
# [1] "N0/N: 0.7; Iteration: 47"
# Time difference of 21.83621 secs
# [1] "N0/N: 0.7; Iteration: 48"
# Time difference of 22.80394 secs
# [1] "N0/N: 0.7; Iteration: 49"
# Time difference of 23.46347 secs
# [1] "N0/N: 0.7; Iteration: 50"
# Time difference of 23.93743 secs
# [1] "N0/N: 0.9; Iteration: 1"
# Time difference of 14.13814 secs
# [1] "N0/N: 0.9; Iteration: 2"
# Time difference of 16.62399 secs
# [1] "N0/N: 0.9; Iteration: 3"
# Time difference of 15.56147 secs
# [1] "N0/N: 0.9; Iteration: 4"
# Time difference of 14.0449 secs
# [1] "N0/N: 0.9; Iteration: 5"
# Time difference of 12.97229 secs
# [1] "N0/N: 0.9; Iteration: 6"
# Time difference of 19.79085 secs
# [1] "N0/N: 0.9; Iteration: 7"
# Time difference of 17.42617 secs
# [1] "N0/N: 0.9; Iteration: 8"
# Time difference of 18.52208 secs
# [1] "N0/N: 0.9; Iteration: 9"
# Time difference of 19.005 secs
# [1] "N0/N: 0.9; Iteration: 10"
# Time difference of 21.32033 secs
# [1] "N0/N: 0.9; Iteration: 11"
# Time difference of 16.60982 secs
# [1] "N0/N: 0.9; Iteration: 12"
# Time difference of 15.25564 secs
# [1] "N0/N: 0.9; Iteration: 13"
# Time difference of 12.63717 secs
# [1] "N0/N: 0.9; Iteration: 14"
# Time difference of 21.69569 secs
# [1] "N0/N: 0.9; Iteration: 15"
# Time difference of 13.21084 secs
# [1] "N0/N: 0.9; Iteration: 16"
# Time difference of 21.67168 secs
# [1] "N0/N: 0.9; Iteration: 17"
# Time difference of 16.18974 secs
# [1] "N0/N: 0.9; Iteration: 18"
# Time difference of 18.43707 secs
# [1] "N0/N: 0.9; Iteration: 19"
# Time difference of 15.75636 secs
# [1] "N0/N: 0.9; Iteration: 20"
# Time difference of 22.35319 secs
# [1] "N0/N: 0.9; Iteration: 21"
# Time difference of 12.89066 secs
# [1] "N0/N: 0.9; Iteration: 22"
# Time difference of 15.1086 secs
# [1] "N0/N: 0.9; Iteration: 23"
# Time difference of 19.97063 secs
# [1] "N0/N: 0.9; Iteration: 24"
# Time difference of 19.91968 secs
# [1] "N0/N: 0.9; Iteration: 25"
# Time difference of 18.56508 secs
# [1] "N0/N: 0.9; Iteration: 26"
# Time difference of 17.54948 secs
# [1] "N0/N: 0.9; Iteration: 27"
# Time difference of 17.09956 secs
# [1] "N0/N: 0.9; Iteration: 28"
# Time difference of 17.36912 secs
# [1] "N0/N: 0.9; Iteration: 29"
# Time difference of 13.51032 secs
# [1] "N0/N: 0.9; Iteration: 30"
# Time difference of 17.47472 secs
# [1] "N0/N: 0.9; Iteration: 31"
# Time difference of 22.18571 secs
# [1] "N0/N: 0.9; Iteration: 32"
# Time difference of 13.83394 secs
# [1] "N0/N: 0.9; Iteration: 33"
# Time difference of 16.55339 secs
# [1] "N0/N: 0.9; Iteration: 34"
# Time difference of 10.85479 secs
# [1] "N0/N: 0.9; Iteration: 35"
# Time difference of 12.30841 secs
# [1] "N0/N: 0.9; Iteration: 36"
# Time difference of 17.62229 secs
# [1] "N0/N: 0.9; Iteration: 37"
# Time difference of 15.28099 secs
# [1] "N0/N: 0.9; Iteration: 38"
# Time difference of 18.92033 secs
# [1] "N0/N: 0.9; Iteration: 39"
# Time difference of 15.4441 secs
# [1] "N0/N: 0.9; Iteration: 40"
# Time difference of 18.36949 secs
# [1] "N0/N: 0.9; Iteration: 41"
# Time difference of 18.90179 secs
# [1] "N0/N: 0.9; Iteration: 42"
# Time difference of 17.75316 secs
# [1] "N0/N: 0.9; Iteration: 43"
# Time difference of 13.84322 secs
# [1] "N0/N: 0.9; Iteration: 44"
# Time difference of 13.02505 secs
# [1] "N0/N: 0.9; Iteration: 45"
# Time difference of 16.79338 secs
# [1] "N0/N: 0.9; Iteration: 46"
# Time difference of 14.07376 secs
# [1] "N0/N: 0.9; Iteration: 47"
# Time difference of 15.93511 secs
# [1] "N0/N: 0.9; Iteration: 48"
# Time difference of 18.78246 secs
# [1] "N0/N: 0.9; Iteration: 49"
# Time difference of 13.46453 secs
# [1] "N0/N: 0.9; Iteration: 50"
# Time difference of 9.923572 secs

# %%
N0RMSEDataForLatex <- aggN0Data %>% mutate(N0_over_N = round(N0/N, 3),
    `RMSE (SE)` = paste(round(RMSE, 3), ' (', round(SE, 3), ')', sep='')) 

N0RMSEDataForLatex <- N0RMSEDataForLatex[c('Method', 'RMSE (SE)', 'N0_over_N')]


N0RMSEDataForLatex <- spread(N0RMSEDataForLatex[, c('Method', "N0_over_N", "RMSE (SE)")], key=N0_over_N, value=`RMSE (SE)`)


N0RMSEDataForLatex<- knitr::kable(N0RMSEDataForLatex, 'latex')

# %% [markdown]
# # Influence of $\rho$ on Performance

# %%
## Chunk 19

signal_to_noise_ratios <- c()

all_rhos <- c(.1, .3, .5, .7, .9)

msesRhoData <- array(NA, dim=c(length(methodNames), draws_per_L, length(all_rhos) ),
                   dimnames=c(list(Method=methodNames), list(Iteration=1:draws_per_L), list(Rho=all_rhos )))




for (this_rho in all_rhos){ 
    
    
  rhoForIndex <- as.character(this_rho)
  
  set.seed(3729)
  
  this_autocorrelation_matrix <- make_rho_mat(rho=this_rho, p=dim(W)[2])
  
  if (design=="staggered_adoption"){ ## Come up with a way to vary the lag in the staggered structure
  
  if(lag_structure == "random"){
    
    ones_we_make <- c(rep(0, N0), pmin(rpois(N-N0, 
                                            lambda=average_treatment_length-1)+1, 
                                      min(max_lag*(N-N0), .8*Time)))
    
  }else if (lag_structure=="constant"){ ## Does not control T-T0
    
    ones_we_make <- c(rep(0, N0), pmin(max_lag*seq(1, (N-N0)), floor(.8*Time)))
      
      }
    
  

}else if (design=="simultaneous_adoption"){
  
  ones_we_make <- c(rep(0, N0), rep(Time-Time0, N-N0))
  
}

  W <- W_maker(N=N, Time=Time, ones_per_row = ones_we_make)

  tau_matrix <- t(apply(W, MARGIN=1, FUN=treated_matrix_creator, 
                      f_of_t=treatment_function, arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff,
                      value=tau))

  treated_units <- as.numeric(which(apply(W, MARGIN=1, FUN = function(x) any(x==1))))
  
  treatment_times <- as.numeric(which(apply(W, MARGIN=2, FUN = function(x) any(x==1))))

  delta_t <- treatment_function(treatment_times-(min(treatment_times)-1),
                              arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff, value=tau)
  
  for (i in 1:number_of_L){
  
 # set.seed(3729)
  
  errors_this_L_did <- rep(NA, draws_per_L)
  
  errors_this_L_sc <- rep(NA, draws_per_L)
  
  errors_this_L_mc_nnm <- rep(NA, draws_per_L)
  
  errors_this_L_sdid <- rep(NA, draws_per_L)
  
  errors_this_L_lapis <- rep(NA, draws_per_L)
  
  errors_this_L_oracle <- rep(NA, draws_per_L)
  
  if (balanced){
    
    U_vec <- rexp(n=N*R, rate=1)

    V_vec <- rexp(n=Time*R, rate=1)
  
    U <- matrix(U_vec, nrow=N, ncol=R, byrow=T)

    V <- matrix(V_vec, nrow=Time, ncol=R, byrow=T)
  
  }else{
    
    U <- matrix(NA, nrow=N, ncol=R, byrow=T)

    V <- matrix(NA, nrow=Time, ncol=R, byrow=T)
    
    for (row_unit in 1:N){
      
      U[row_unit,] <- rpois(n=R, lambda=sqrt(row_unit/N))
      
    } 
    
    for (row_time in 1:Time){
      
      V[row_time,] <- rpois(n=R, lambda=sqrt(row_time/Time))
      
    }
    
  }

  L <- L_scaling*(U %*% t(V))
  
  for (j in 1:draws_per_L){
      
    startTime <- Sys.time()
    
    if (error == 'gaussian'){
      
      Y <- norta(number=N, corr_mat=this_autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W, distribution='gaussian',
                 scalar_sigma=sqrt(sigma_squared))
      
    } else if (error == 't'){
    
      Y <- norta(number=N, corr_mat=this_autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='t', scalar_sigma=sqrt(sigma_squared))
    
    } else if (error == 'poisson'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=this_autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='poisson', scalar_sigma=sqrt(sigma_squared))
      
    } else if (error == 'scaled_gamma'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=this_autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='scaled_gamma', scalar_sigma=sqrt(sigma_squared))
      
    }else if (error == 'exponential'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=this_autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='exponential', scalar_sigma=sqrt(sigma_squared))

    }
    
    #estimated_rank <- rank_estimator(Y, W, num_iter=100, K=5, 
    #                      lambda_grid=c(0, 10^seq(-20, 0, 2)), 
    #                      method="threshold")
    
    #Y_0_LAPIS <- LAPIS(Y, rank_threshold=estimated_rank,
    #                                    min_iter=1, max_iter=max_iter,
    #                                    tolerance=tolerance, W=W)
    
    
    if (N-N0 > 1){
    
    treatment_subjects_averaged <- colMeans(Y[1:dim(Y)[1] > N0,])
    
    W_averaged <- colMeans(W[1:dim(W)[1] > N0,])
    
    new_Y <- rbind(Y[1:dim(Y)[1] <= N0,], treatment_subjects_averaged)
    
    new_W <- rbind(W[1:dim(Y)[1] <= N0,], W_averaged)
    
    } else {
    
      new_Y <- Y
    
      new_W <- W
      
      
    }
    
    tau_estimate_did <- DID(Y=Y, W=W)
    
    tau_estimate_sc <- synth_cont(Y=Y, W=W)
    
    tau_estimate_sdid <- SDID_general(Y=Y, W=W,
                 iterations_for_coord_desc=100)
    
    mc_nnm_info <- matrix_completion_causal(Y=Y, W=W, num_iter=1000, K=5, 
                            lambda_grid=c(10^seq(-4,2,1), seq(2,5,1)),
                            tol=1e-04)
    
    L_mc_nnm <- mc_nnm_info$L_hat
    
    tau_estimate_mc_nnm <- treat.estimator(Y=Y, L.hat=L_mc_nnm, W=W)
      
      
    estFactors <- rankMatrix(mc_nnm_info$L_hat)[1]  
    
    lapis_info <- LAPIS_with_rank_estimation(Y=Y, 
                           W=W, initial_rank=rankMatrix(mc_nnm_info$L_hat)[1],
                           tolerance=tolerance, 
                           min_iter=min_iter, max_iter=max_iter,   
                           mu_grid=NULL, warm_start=F, method = 'explicit_tau')
      
      
    tau_estimate_lapis <- treat.estimator(Y, lapis_info, W)
    
    tau_estimate_oracle <- treat.estimator(Y=Y, L.hat=L, W=W)
    
    ## Only oracle in the sense that we know L
    
    error_tau_sc <- mean(abs(tau_estimate_sc-delta_t)^2)
    
    error_tau_did <- mean(abs(tau_estimate_did-delta_t)^2)
    
    error_tau_mc_nnm <- mean(abs(tau_estimate_mc_nnm-delta_t)^2)
    
    error_tau_sdid <- mean(abs(tau_estimate_sdid-delta_t)^2)
    
    error_tau_lapis <- mean(abs(tau_estimate_lapis-delta_t)^2)
    
    error_tau_oracle <- mean(abs(tau_estimate_oracle-delta_t)^2)

    errors_this_L_did[j] <- error_tau_did
    
    errors_this_L_sc[j] <- error_tau_sc
      
    errors_this_L_mc_nnm[j] <- error_tau_mc_nnm
    
    errors_this_L_sdid[j] <- error_tau_sdid
    
    errors_this_L_lapis[j] <- error_tau_lapis
    
    errors_this_L_oracle[j] <- error_tau_oracle

    msesRhoData['DID', j, rhoForIndex] <- mean(abs(tau_estimate_did-delta_t)^2)
    
    msesRhoData['SC', j, rhoForIndex] <- mean(abs(tau_estimate_sc-delta_t)^2)
    
    msesRhoData['MC-NNM', j, rhoForIndex] <- mean(abs(tau_estimate_mc_nnm-delta_t)^2)
    
    msesRhoData['SDID', j, rhoForIndex] <- mean(abs(tau_estimate_sdid-delta_t)^2)
    
    msesRhoData['LAPIS', j, rhoForIndex] <- mean(abs(tau_estimate_lapis-delta_t)^2)
    
    msesRhoData['ORACLE', j, rhoForIndex] <- mean(abs(tau_estimate_oracle-delta_t)^2)
      
    endTime <- Sys.time()
      
    outMessage <- paste('rho: ', this_rho, '; Iteration: ', j, sep='')
      
    print(outMessage)
      
    print(difftime(endTime, startTime, 'mins'))

  }   

}
  
  
  signal_to_noise_ratios <- c(signal_to_noise_ratios, (svd(L)$d[R]/svd(sigma_squared*this_autocorrelation_matrix)$d[1]))
       
       }
  

meltedRhoData <- as_tibble(as.tbl_cube(msesRhoData, met='MSE'))

meltedRhoData$Method <- factor(meltedRhoData$Method, levels=methodNames)                                                  
                                            
meltedRhoData  <- meltedRhoData  %>% filter(Method !='DID') 
 
aggRhoData <- meltedRhoData %>% group_by(Method, Rho) %>% dplyr::summarize(RMSE = mean(sqrt(MSE)),
                                                                SE = sd(sqrt(MSE))/sqrt(n()))

p_mse_vs_rho <- (ggplot(aggRhoData, aes(x=Rho, y=RMSE, col=Method)) + geom_line(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of the Correlation Parameter") 
                +xlab("rho") + ylab('RMSE'))
                                            
p_mse_vs_rho_uncertainty <- (ggplot(meltedRhoData, aes(x=Rho, y=sqrt(MSE), col=Method)) + geom_smooth(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of Correlation Parameter") 
                +xlab("rho") + ylab('RMSE'))
# Out:
# [1] "rho: 0.1; Iteration: 1"
# Time difference of 19.48487 secs
# [1] "rho: 0.1; Iteration: 2"
# Time difference of 12.79294 secs
# [1] "rho: 0.1; Iteration: 3"
# Time difference of 18.39989 secs
# [1] "rho: 0.1; Iteration: 4"
# Time difference of 14.87526 secs
# [1] "rho: 0.1; Iteration: 5"
# Time difference of 13.26751 secs
# [1] "rho: 0.1; Iteration: 6"
# Time difference of 15.35655 secs
# [1] "rho: 0.1; Iteration: 7"
# Time difference of 18.42995 secs
# [1] "rho: 0.1; Iteration: 8"
# Time difference of 20.05499 secs
# [1] "rho: 0.1; Iteration: 9"
# Time difference of 15.70153 secs
# [1] "rho: 0.1; Iteration: 10"
# Time difference of 19.37526 secs
# [1] "rho: 0.1; Iteration: 11"
# Time difference of 14.02362 secs
# [1] "rho: 0.1; Iteration: 12"
# Time difference of 17.83485 secs
# [1] "rho: 0.1; Iteration: 13"
# Time difference of 21.86055 secs
# [1] "rho: 0.1; Iteration: 14"
# Time difference of 16.87547 secs
# [1] "rho: 0.1; Iteration: 15"
# Time difference of 19.59537 secs
# [1] "rho: 0.1; Iteration: 16"
# Time difference of 19.58091 secs
# [1] "rho: 0.1; Iteration: 17"
# Time difference of 23.38303 secs
# [1] "rho: 0.1; Iteration: 18"
# Time difference of 13.89116 secs
# [1] "rho: 0.1; Iteration: 19"
# Time difference of 17.20551 secs
# [1] "rho: 0.1; Iteration: 20"
# Time difference of 15.80993 secs
# [1] "rho: 0.1; Iteration: 21"
# Time difference of 17.75376 secs
# [1] "rho: 0.1; Iteration: 22"
# Time difference of 15.37747 secs
# [1] "rho: 0.1; Iteration: 23"
# Time difference of 13.91351 secs
# [1] "rho: 0.1; Iteration: 24"
# Time difference of 18.42873 secs
# [1] "rho: 0.1; Iteration: 25"
# Time difference of 16.81068 secs
# [1] "rho: 0.1; Iteration: 26"
# Time difference of 17.92358 secs
# [1] "rho: 0.1; Iteration: 27"
# Time difference of 17.34681 secs
# [1] "rho: 0.1; Iteration: 28"
# Time difference of 14.93844 secs
# [1] "rho: 0.1; Iteration: 29"
# Time difference of 18.50333 secs
# [1] "rho: 0.1; Iteration: 30"
# Time difference of 16.69968 secs
# [1] "rho: 0.1; Iteration: 31"
# Time difference of 15.31759 secs
# [1] "rho: 0.1; Iteration: 32"
# Time difference of 15.32483 secs
# [1] "rho: 0.1; Iteration: 33"
# Time difference of 17.16578 secs
# [1] "rho: 0.1; Iteration: 34"
# Time difference of 15.46799 secs
# [1] "rho: 0.1; Iteration: 35"
# Time difference of 12.59757 secs
# [1] "rho: 0.1; Iteration: 36"
# Time difference of 14.31135 secs
# [1] "rho: 0.1; Iteration: 37"
# Time difference of 17.00951 secs
# [1] "rho: 0.1; Iteration: 38"
# Time difference of 17.06363 secs
# [1] "rho: 0.1; Iteration: 39"
# Time difference of 18.48188 secs
# [1] "rho: 0.1; Iteration: 40"
# Time difference of 17.54752 secs
# [1] "rho: 0.1; Iteration: 41"
# Time difference of 14.96219 secs
# [1] "rho: 0.1; Iteration: 42"
# Time difference of 13.08828 secs
# [1] "rho: 0.1; Iteration: 43"
# Time difference of 19.33079 secs
# [1] "rho: 0.1; Iteration: 44"
# Time difference of 18.56087 secs
# [1] "rho: 0.1; Iteration: 45"
# Time difference of 20.34127 secs
# [1] "rho: 0.1; Iteration: 46"
# Time difference of 14.18723 secs
# [1] "rho: 0.1; Iteration: 47"
# Time difference of 15.8725 secs
# [1] "rho: 0.1; Iteration: 48"
# Time difference of 15.02996 secs
# [1] "rho: 0.1; Iteration: 49"
# Time difference of 19.02715 secs
# [1] "rho: 0.1; Iteration: 50"
# Time difference of 16.37174 secs
# [1] "rho: 0.3; Iteration: 1"
# Time difference of 18.54243 secs
# [1] "rho: 0.3; Iteration: 2"
# Time difference of 19.56887 secs
# [1] "rho: 0.3; Iteration: 3"
# Time difference of 21.51205 secs
# [1] "rho: 0.3; Iteration: 4"
# Time difference of 17.7628 secs
# [1] "rho: 0.3; Iteration: 5"
# Time difference of 12.13277 secs
# [1] "rho: 0.3; Iteration: 6"
# Time difference of 16.0704 secs
# [1] "rho: 0.3; Iteration: 7"
# Time difference of 13.79914 secs
# [1] "rho: 0.3; Iteration: 8"
# Time difference of 16.31321 secs
# [1] "rho: 0.3; Iteration: 9"
# Time difference of 19.89749 secs
# [1] "rho: 0.3; Iteration: 10"
# Time difference of 19.05184 secs
# [1] "rho: 0.3; Iteration: 11"
# Time difference of 11.99592 secs
# [1] "rho: 0.3; Iteration: 12"
# Time difference of 23.34379 secs
# [1] "rho: 0.3; Iteration: 13"
# Time difference of 14.77772 secs
# [1] "rho: 0.3; Iteration: 14"
# Time difference of 19.89362 secs
# [1] "rho: 0.3; Iteration: 15"
# Time difference of 17.80224 secs
# [1] "rho: 0.3; Iteration: 16"
# Time difference of 16.81275 secs
# [1] "rho: 0.3; Iteration: 17"
# Time difference of 14.35104 secs
# [1] "rho: 0.3; Iteration: 18"
# Time difference of 17.86628 secs
# [1] "rho: 0.3; Iteration: 19"
# Time difference of 17.93576 secs
# [1] "rho: 0.3; Iteration: 20"
# Time difference of 15.81786 secs
# [1] "rho: 0.3; Iteration: 21"
# Time difference of 20.70308 secs
# [1] "rho: 0.3; Iteration: 22"
# Time difference of 16.04247 secs
# [1] "rho: 0.3; Iteration: 23"
# Time difference of 17.09664 secs
# [1] "rho: 0.3; Iteration: 24"
# Time difference of 11.68983 secs
# [1] "rho: 0.3; Iteration: 25"
# Time difference of 21.09144 secs
# [1] "rho: 0.3; Iteration: 26"
# Time difference of 14.45075 secs
# [1] "rho: 0.3; Iteration: 27"
# Time difference of 10.25183 secs
# [1] "rho: 0.3; Iteration: 28"
# Time difference of 16.90004 secs
# [1] "rho: 0.3; Iteration: 29"
# Time difference of 11.22837 secs
# [1] "rho: 0.3; Iteration: 30"
# Time difference of 16.99439 secs
# [1] "rho: 0.3; Iteration: 31"
# Time difference of 15.44427 secs
# [1] "rho: 0.3; Iteration: 32"
# Time difference of 17.32594 secs
# [1] "rho: 0.3; Iteration: 33"
# Time difference of 19.20518 secs
# [1] "rho: 0.3; Iteration: 34"
# Time difference of 16.25871 secs
# [1] "rho: 0.3; Iteration: 35"
# Time difference of 17.24004 secs
# [1] "rho: 0.3; Iteration: 36"
# Time difference of 20.72786 secs
# [1] "rho: 0.3; Iteration: 37"
# Time difference of 18.40775 secs
# [1] "rho: 0.3; Iteration: 38"
# Time difference of 17.93362 secs
# [1] "rho: 0.3; Iteration: 39"
# Time difference of 14.4851 secs
# [1] "rho: 0.3; Iteration: 40"
# Time difference of 16.35649 secs
# [1] "rho: 0.3; Iteration: 41"
# Time difference of 19.84411 secs
# [1] "rho: 0.3; Iteration: 42"
# Time difference of 15.49617 secs
# [1] "rho: 0.3; Iteration: 43"
# Time difference of 18.07463 secs
# [1] "rho: 0.3; Iteration: 44"
# Time difference of 16.342 secs
# [1] "rho: 0.3; Iteration: 45"
# Time difference of 17.75336 secs
# [1] "rho: 0.3; Iteration: 46"
# Time difference of 18.90793 secs
# [1] "rho: 0.3; Iteration: 47"
# Time difference of 18.41796 secs
# [1] "rho: 0.3; Iteration: 48"
# Time difference of 19.9432 secs
# [1] "rho: 0.3; Iteration: 49"
# Time difference of 15.53137 secs
# [1] "rho: 0.3; Iteration: 50"
# Time difference of 14.48167 secs
# [1] "rho: 0.5; Iteration: 1"
# Time difference of 15.54047 secs
# [1] "rho: 0.5; Iteration: 2"
# Time difference of 11.87581 secs
# [1] "rho: 0.5; Iteration: 3"
# Time difference of 14.36788 secs
# [1] "rho: 0.5; Iteration: 4"
# Time difference of 19.96508 secs
# [1] "rho: 0.5; Iteration: 5"
# Time difference of 13.58605 secs
# [1] "rho: 0.5; Iteration: 6"
# Time difference of 15.07156 secs
# [1] "rho: 0.5; Iteration: 7"
# Time difference of 16.16446 secs
# [1] "rho: 0.5; Iteration: 8"
# Time difference of 13.93892 secs
# [1] "rho: 0.5; Iteration: 9"
# Time difference of 18.99989 secs
# [1] "rho: 0.5; Iteration: 10"
# Time difference of 16.74949 secs
# [1] "rho: 0.5; Iteration: 11"
# Time difference of 16.58951 secs
# [1] "rho: 0.5; Iteration: 12"
# Time difference of 17.96373 secs
# [1] "rho: 0.5; Iteration: 13"
# Time difference of 11.10597 secs
# [1] "rho: 0.5; Iteration: 14"
# Time difference of 15.22512 secs
# [1] "rho: 0.5; Iteration: 15"
# Time difference of 16.33096 secs
# [1] "rho: 0.5; Iteration: 16"
# Time difference of 18.28963 secs
# [1] "rho: 0.5; Iteration: 17"
# Time difference of 17.87353 secs
# [1] "rho: 0.5; Iteration: 18"
# Time difference of 15.10347 secs
# [1] "rho: 0.5; Iteration: 19"
# Time difference of 12.87309 secs
# [1] "rho: 0.5; Iteration: 20"
# Time difference of 16.17532 secs
# [1] "rho: 0.5; Iteration: 21"
# Time difference of 15.57573 secs
# [1] "rho: 0.5; Iteration: 22"
# Time difference of 12.20546 secs
# [1] "rho: 0.5; Iteration: 23"
# Time difference of 19.15888 secs
# [1] "rho: 0.5; Iteration: 24"
# Time difference of 17.24251 secs
# [1] "rho: 0.5; Iteration: 25"
# Time difference of 17.03599 secs
# [1] "rho: 0.5; Iteration: 26"
# Time difference of 14.36471 secs
# [1] "rho: 0.5; Iteration: 27"
# Time difference of 15.17647 secs
# [1] "rho: 0.5; Iteration: 28"
# Time difference of 21.89776 secs
# [1] "rho: 0.5; Iteration: 29"
# Time difference of 11.57311 secs
# [1] "rho: 0.5; Iteration: 30"
# Time difference of 16.05523 secs
# [1] "rho: 0.5; Iteration: 31"
# Time difference of 14.37155 secs
# [1] "rho: 0.5; Iteration: 32"
# Time difference of 19.68325 secs
# [1] "rho: 0.5; Iteration: 33"
# Time difference of 14.98066 secs
# [1] "rho: 0.5; Iteration: 34"
# Time difference of 18.41484 secs
# [1] "rho: 0.5; Iteration: 35"
# Time difference of 12.84936 secs
# [1] "rho: 0.5; Iteration: 36"
# Time difference of 17.04717 secs
# [1] "rho: 0.5; Iteration: 37"
# Time difference of 16.36257 secs
# [1] "rho: 0.5; Iteration: 38"
# Time difference of 14.5481 secs
# [1] "rho: 0.5; Iteration: 39"
# Time difference of 16.51622 secs
# [1] "rho: 0.5; Iteration: 40"
# Time difference of 20.12687 secs
# [1] "rho: 0.5; Iteration: 41"
# Time difference of 16.43906 secs
# [1] "rho: 0.5; Iteration: 42"
# Time difference of 21.08792 secs
# [1] "rho: 0.5; Iteration: 43"
# Time difference of 16.74814 secs
# [1] "rho: 0.5; Iteration: 44"
# Time difference of 15.81355 secs
# [1] "rho: 0.5; Iteration: 45"
# Time difference of 16.29101 secs
# [1] "rho: 0.5; Iteration: 46"
# Time difference of 15.20772 secs
# [1] "rho: 0.5; Iteration: 47"
# Time difference of 22.97562 secs
# [1] "rho: 0.5; Iteration: 48"
# Time difference of 13.40562 secs
# [1] "rho: 0.5; Iteration: 49"
# Time difference of 20.76111 secs
# [1] "rho: 0.5; Iteration: 50"
# Time difference of 15.29931 secs
# [1] "rho: 0.7; Iteration: 1"
# Time difference of 16.32324 secs
# [1] "rho: 0.7; Iteration: 2"
# Time difference of 17.28465 secs
# [1] "rho: 0.7; Iteration: 3"
# Time difference of 13.35989 secs
# [1] "rho: 0.7; Iteration: 4"
# Time difference of 18.26123 secs
# [1] "rho: 0.7; Iteration: 5"
# Time difference of 20.38685 secs
# [1] "rho: 0.7; Iteration: 6"
# Time difference of 17.67685 secs
# [1] "rho: 0.7; Iteration: 7"
# Time difference of 13.83555 secs
# [1] "rho: 0.7; Iteration: 8"
# Time difference of 15.06218 secs
# [1] "rho: 0.7; Iteration: 9"
# Time difference of 11.83262 secs
# [1] "rho: 0.7; Iteration: 10"
# Time difference of 22.1306 secs
# [1] "rho: 0.7; Iteration: 11"
# Time difference of 17.52906 secs
# [1] "rho: 0.7; Iteration: 12"
# Time difference of 14.65689 secs
# [1] "rho: 0.7; Iteration: 13"
# Time difference of 20.21396 secs
# [1] "rho: 0.7; Iteration: 14"
# Time difference of 10.1232 secs
# [1] "rho: 0.7; Iteration: 15"
# Time difference of 14.65734 secs
# [1] "rho: 0.7; Iteration: 16"
# Time difference of 15.48926 secs
# [1] "rho: 0.7; Iteration: 17"
# Time difference of 19.17576 secs
# [1] "rho: 0.7; Iteration: 18"
# Time difference of 16.77887 secs
# [1] "rho: 0.7; Iteration: 19"
# Time difference of 17.64907 secs
# [1] "rho: 0.7; Iteration: 20"
# Time difference of 15.30522 secs
# [1] "rho: 0.7; Iteration: 21"
# Time difference of 15.51215 secs
# [1] "rho: 0.7; Iteration: 22"
# Time difference of 15.2107 secs
# [1] "rho: 0.7; Iteration: 23"
# Time difference of 16.20168 secs
# [1] "rho: 0.7; Iteration: 24"
# Time difference of 14.31576 secs
# [1] "rho: 0.7; Iteration: 25"
# Time difference of 17.56044 secs
# [1] "rho: 0.7; Iteration: 26"
# Time difference of 17.09473 secs
# [1] "rho: 0.7; Iteration: 27"
# Time difference of 14.94512 secs
# [1] "rho: 0.7; Iteration: 28"
# Time difference of 16.91172 secs
# [1] "rho: 0.7; Iteration: 29"
# Time difference of 22.25257 secs
# [1] "rho: 0.7; Iteration: 30"
# Time difference of 12.76569 secs
# [1] "rho: 0.7; Iteration: 31"
# Time difference of 14.81575 secs
# [1] "rho: 0.7; Iteration: 32"
# Time difference of 17.83478 secs
# [1] "rho: 0.7; Iteration: 33"
# Time difference of 21.67929 secs
# [1] "rho: 0.7; Iteration: 34"
# Time difference of 17.96359 secs
# [1] "rho: 0.7; Iteration: 35"
# Time difference of 15.71931 secs
# [1] "rho: 0.7; Iteration: 36"
# Time difference of 17.63244 secs
# [1] "rho: 0.7; Iteration: 37"
# Time difference of 15.31772 secs
# [1] "rho: 0.7; Iteration: 38"
# Time difference of 18.62947 secs
# [1] "rho: 0.7; Iteration: 39"
# Time difference of 14.1051 secs
# [1] "rho: 0.7; Iteration: 40"
# Time difference of 14.29777 secs
# [1] "rho: 0.7; Iteration: 41"
# Time difference of 12.30406 secs
# [1] "rho: 0.7; Iteration: 42"
# Time difference of 16.20652 secs
# [1] "rho: 0.7; Iteration: 43"
# Time difference of 16.87966 secs
# [1] "rho: 0.7; Iteration: 44"
# Time difference of 10.64345 secs
# [1] "rho: 0.7; Iteration: 45"
# Time difference of 13.60915 secs
# [1] "rho: 0.7; Iteration: 46"
# Time difference of 15.59926 secs
# [1] "rho: 0.7; Iteration: 47"
# Time difference of 15.77863 secs
# [1] "rho: 0.7; Iteration: 48"
# Time difference of 16.29173 secs
# [1] "rho: 0.7; Iteration: 49"
# Time difference of 16.32461 secs
# [1] "rho: 0.7; Iteration: 50"
# Time difference of 16.08987 secs
# [1] "rho: 0.9; Iteration: 1"
# Time difference of 11.72496 secs
# [1] "rho: 0.9; Iteration: 2"
# Time difference of 16.5362 secs
# [1] "rho: 0.9; Iteration: 3"
# Time difference of 16.08092 secs
# [1] "rho: 0.9; Iteration: 4"
# Time difference of 17.45985 secs
# [1] "rho: 0.9; Iteration: 5"
# Time difference of 14.30351 secs
# [1] "rho: 0.9; Iteration: 6"
# Time difference of 11.48509 secs
# [1] "rho: 0.9; Iteration: 7"
# Time difference of 17.58293 secs
# [1] "rho: 0.9; Iteration: 8"
# Time difference of 15.91761 secs
# [1] "rho: 0.9; Iteration: 9"
# Time difference of 15.97041 secs
# [1] "rho: 0.9; Iteration: 10"
# Time difference of 15.64895 secs
# [1] "rho: 0.9; Iteration: 11"
# Time difference of 18.75818 secs
# [1] "rho: 0.9; Iteration: 12"
# Time difference of 18.07189 secs
# [1] "rho: 0.9; Iteration: 13"
# Time difference of 15.99533 secs
# [1] "rho: 0.9; Iteration: 14"
# Time difference of 17.67112 secs
# [1] "rho: 0.9; Iteration: 15"
# Time difference of 15.14634 secs
# [1] "rho: 0.9; Iteration: 16"
# Time difference of 13.45285 secs
# [1] "rho: 0.9; Iteration: 17"
# Time difference of 17.64499 secs
# [1] "rho: 0.9; Iteration: 18"
# Time difference of 12.50024 secs
# [1] "rho: 0.9; Iteration: 19"
# Time difference of 16.10295 secs
# [1] "rho: 0.9; Iteration: 20"
# Time difference of 11.21779 secs
# [1] "rho: 0.9; Iteration: 21"
# Time difference of 14.99667 secs
# [1] "rho: 0.9; Iteration: 22"
# Time difference of 13.39122 secs
# [1] "rho: 0.9; Iteration: 23"
# Time difference of 10.64257 secs
# [1] "rho: 0.9; Iteration: 24"
# Time difference of 14.15033 secs
# [1] "rho: 0.9; Iteration: 25"
# Time difference of 12.7815 secs
# [1] "rho: 0.9; Iteration: 26"
# Time difference of 10.57803 secs
# [1] "rho: 0.9; Iteration: 27"
# Time difference of 12.42573 secs
# [1] "rho: 0.9; Iteration: 28"
# Time difference of 11.60328 secs
# [1] "rho: 0.9; Iteration: 29"
# Time difference of 13.21569 secs
# [1] "rho: 0.9; Iteration: 30"
# Time difference of 15.13463 secs
# [1] "rho: 0.9; Iteration: 31"
# Time difference of 12.51923 secs
# [1] "rho: 0.9; Iteration: 32"
# Time difference of 15.71774 secs
# [1] "rho: 0.9; Iteration: 33"
# Time difference of 12.1845 secs
# [1] "rho: 0.9; Iteration: 34"
# Time difference of 9.107491 secs
# [1] "rho: 0.9; Iteration: 35"
# Time difference of 15.93848 secs
# [1] "rho: 0.9; Iteration: 36"
# Time difference of 12.40717 secs
# [1] "rho: 0.9; Iteration: 37"
# Time difference of 13.62389 secs
# [1] "rho: 0.9; Iteration: 38"
# Time difference of 18.03001 secs
# [1] "rho: 0.9; Iteration: 39"
# Time difference of 12.93451 secs
# [1] "rho: 0.9; Iteration: 40"
# Time difference of 15.83359 secs
# [1] "rho: 0.9; Iteration: 41"
# Time difference of 12.87239 secs
# [1] "rho: 0.9; Iteration: 42"
# Time difference of 16.85786 secs
# [1] "rho: 0.9; Iteration: 43"
# Time difference of 16.52665 secs
# [1] "rho: 0.9; Iteration: 44"
# Time difference of 16.43392 secs
# [1] "rho: 0.9; Iteration: 45"
# Time difference of 14.38895 secs
# [1] "rho: 0.9; Iteration: 46"
# Time difference of 16.63943 secs
# [1] "rho: 0.9; Iteration: 47"
# Time difference of 14.33646 secs
# [1] "rho: 0.9; Iteration: 48"
# Time difference of 13.46703 secs
# [1] "rho: 0.9; Iteration: 49"
# Time difference of 15.55561 secs
# [1] "rho: 0.9; Iteration: 50"
# Time difference of 12.99253 secs

# %%
rhoRMSEDataForLatex <- aggRhoData %>% mutate(
    `RMSE (SE)` = paste(round(RMSE, 3), ' (', round(SE, 3), ')', sep='')) 

rhoRMSEDataForLatex <- rhoRMSEDataForLatex[c('Method', 'RMSE (SE)', 'Rho')]


rhoRMSEDataForLatex <- spread(rhoRMSEDataForLatex, key=Rho, value=`RMSE (SE)`)


rhoRMSEDataForLatex<- knitr::kable(rhoRMSEDataForLatex, 'latex')

# %% [markdown]
# # Influence of $\tau$ on Performance

# %%
all_taus <- c(1, 11, 16, 21, 26)

msesTauData <- array(NA, dim=c(length(methodNames), draws_per_L, length(all_taus) ),
                   dimnames=c(list(Method=methodNames), list(Iteration=1:draws_per_L), list(Tau=all_taus )))

for (this_tau in all_taus){

  set.seed(3729)
    
  tauForIndex <- as.character(this_tau)
  
  if (design=="staggered_adoption"){ ## Come up with a way to vary the lag in the staggered structure
  
  if(lag_structure == "random"){
    
    ones_we_make <- c(rep(0, N0), pmin(rpois(N-N0, 
                                            lambda=average_treatment_length-1)+1, 
                                      min(max_lag*(N-N0), .8*Time)))
    
  }else if (lag_structure=="constant"){ ## Does not control T-T0
    
    ones_we_make <- c(rep(0, N0), pmin(max_lag*seq(1, (N-N0)), floor(.8*Time)))
    
  }

}else if (design=="simultaneous_adoption"){
  
  ones_we_make <- c(rep(0, N0), rep(Time-Time0, N-N0))
  
}

  W <- W_maker(N=N, Time=Time, ones_per_row = ones_we_make)

  this_tau_matrix <- t(apply(W, MARGIN=1, FUN=treated_matrix_creator, f_of_t=delta_t_constant,
                        value=this_tau))

  treated_units <- as.numeric(which(apply(W, MARGIN=1, FUN = function(x) any(x==1))))
  
  treatment_times <- as.numeric(which(apply(W, MARGIN=2, FUN = function(x) any(x==1))))

  delta_t <- delta_t_constant(treatment_times-(min(treatment_times)-1), value=this_tau)
  
  treated_units <- as.numeric(which(apply(W, MARGIN=1, FUN = function(x) any(x==1))))
  
  treatment_times <- as.numeric(which(apply(W, MARGIN=2, FUN = function(x) any(x==1))))
  
  autocorrelation_matrix <- make_rho_mat(rho=rho_parameter, p=dim(W)[2])

  
  for (i in 1:number_of_L){
    
   # set.seed(3729)
    
    if (balanced){
      
      U_vec <- rexp(n=N*R, rate=1)
  
      V_vec <- rexp(n=Time*R, rate=1)
    
      U <- matrix(U_vec, nrow=N, ncol=R, byrow=T)
  
      V <- matrix(V_vec, nrow=Time, ncol=R, byrow=T)
    
    }else{
      
      U <- matrix(NA, nrow=N, ncol=R, byrow=T)
  
      V <- matrix(NA, nrow=Time, ncol=R, byrow=T)
      
      for (row_unit in 1:N){
        
        U[row_unit,] <- rpois(n=R, lambda=sqrt(row_unit/N))
        
      } 
      
      for (row_time in 1:Time){
        
        V[row_time,] <- rpois(n=R, lambda=sqrt(row_time/Time))
        
      }
      
    }
  
    L <- L_scaling*(U %*% t(V))
    
    for (j in 1:draws_per_L){
        
      startTime <- Sys.time()
      
      if (error == 'gaussian'){
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+this_tau_matrix*W, distribution='gaussian',
                   scalar_sigma=sqrt(sigma_squared))
        
      } else if (error == 't'){
      
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+this_tau_matrix*W,
                   distribution='t', scalar_sigma=sqrt(sigma_squared))
      
      } else if (error == 'poisson'){
        
        if (balanced == F){
        
          L <- abs(L)+1
          
        }
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+this_tau_matrix*W,
                   distribution='poisson', scalar_sigma=sqrt(sigma_squared))
        
      } else if (error == 'scaled_gamma'){
        
        if (balanced == F){
        
          L <- abs(L)+1
          
        }
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+this_tau_matrix*W,
                   distribution='scaled_gamma', scalar_sigma=sqrt(sigma_squared))
        
      }else if (error == 'exponential'){
        
        if (balanced == F){
        
          L <- abs(L)+1
          
        }
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+this_tau_matrix*W,
                   distribution='exponential', scalar_sigma=sqrt(sigma_squared))
  
      }
      
      #estimated_rank <- rank_estimator(Y, W, num_iter=100, K=5, 
      #                      lambda_grid=c(0, 10^seq(-20, 0, 2)), 
      #                      method="threshold")
      
      #Y_0_LAPIS <- LAPIS(Y, rank_threshold=estimated_rank,
      #                                    min_iter=1, max_iter=max_iter,
      #                                    tolerance=tolerance, W=W)
      
      
      if (N-N0 > 1){
      
      treatment_subjects_averaged <- colMeans(Y[1:dim(Y)[1] > N0,])
      
      W_averaged <- colMeans(W[1:dim(W)[1] > N0,])
      
      new_Y <- rbind(Y[1:dim(Y)[1] <= N0,], treatment_subjects_averaged)
      
      new_W <- rbind(W[1:dim(Y)[1] <= N0,], W_averaged)
      
      } else {
      
        new_Y <- Y
      
        new_W <- W
        
        
      }
      
      tau_estimate_did <- DID(Y=Y, W=W)
      
      tau_estimate_sc <- synth_cont(Y=Y, W=W)

      tau_estimate_sdid <- SDID_general(Y=Y, W=W,
                   iterations_for_coord_desc=100)
      
      mc_nnm_info <- matrix_completion_causal(Y=Y, W=W, num_iter=1000, K=5, 
                            lambda_grid=c(10^seq(-4,2,1), seq(2,5,1)),
                            tol=1e-04)
    
    L_mc_nnm <- mc_nnm_info$L_hat
    
    tau_estimate_mc_nnm <- treat.estimator(Y=Y, L.hat=L_mc_nnm, W=W)
        
        
    estFactors <- rankMatrix(mc_nnm_info$L_hat)[1]  
    
    lapis_info <- LAPIS_with_rank_estimation(Y=Y, 
                           W=W, initial_rank=rankMatrix(mc_nnm_info$L_hat)[1],
                           tolerance=tolerance, 
                           min_iter=min_iter, max_iter=max_iter,   
                           mu_grid=NULL, warm_start=F, method = 'explicit_tau')
      
      
    tau_estimate_lapis <- treat.estimator(Y, lapis_info, W)
    
    
    # tau_estimate_mc_nnm
    
    ## Only oracle in the sense that we know L
    
    tau_estimate_oracle <- treat.estimator(Y=Y, L.hat=L, W=W)
  
    msesTauData['DID', j, tauForIndex] <- mean(abs(tau_estimate_did-this_tau)^2)
    
    msesTauData['SC', j, tauForIndex] <- mean(abs(tau_estimate_sc-this_tau)^2)
    
    msesTauData['MC-NNM', j, tauForIndex] <- mean(abs(tau_estimate_mc_nnm-this_tau)^2)
    
    msesTauData['SDID', j, tauForIndex] <- mean(abs(tau_estimate_sdid-this_tau)^2)
    
    msesTauData['LAPIS', j, tauForIndex] <- mean(abs(tau_estimate_lapis-this_tau)^2)
    
    msesTauData['ORACLE', j, tauForIndex] <- mean(abs(tau_estimate_oracle-this_tau)^2)
        
    endTime <- Sys.time()
        
    outMessage <- paste('tau: ', this_tau, '; Iteration: ', j, sep='')
      
    print(outMessage)
      
    print(difftime(endTime, startTime, 'mins'))
  
    }


}

}
                                            
                                            
 meltedTauData <- as_tibble(as.tbl_cube(msesTauData, met='MSE'))

meltedTauData$Method <- factor(meltedTauData$Method, levels=methodNames)                                                  
                                            
meltedTauData  <- meltedTauData  %>% filter(Method !='DID') 
 
aggTauData <- meltedTauData %>% group_by(Method, Tau) %>% dplyr::summarize(RMSE = mean(sqrt(MSE)),
                                                                SE = sd(sqrt(MSE))/sqrt(n()))

p_mse_vs_tau <- (ggplot(aggTauData, aes(x=Tau, y=RMSE, col=Method)) + geom_line(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of Tau") )
                                            
p_mse_vs_tau_uncertainty <- (ggplot(meltedTauData, aes(x=Tau, y=sqrt(MSE), col=Method)) + geom_smooth(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of Tau") )
# Out:
# [1] "tau: 1; Iteration: 1"
# Time difference of 14.28889 secs
# [1] "tau: 1; Iteration: 2"
# Time difference of 17.22812 secs
# [1] "tau: 1; Iteration: 3"
# Time difference of 12.97792 secs
# [1] "tau: 1; Iteration: 4"
# Time difference of 17.29116 secs
# [1] "tau: 1; Iteration: 5"
# Time difference of 17.58088 secs
# [1] "tau: 1; Iteration: 6"
# Time difference of 17.8273 secs
# [1] "tau: 1; Iteration: 7"
# Time difference of 17.46237 secs
# [1] "tau: 1; Iteration: 8"
# Time difference of 17.14398 secs
# [1] "tau: 1; Iteration: 9"
# Time difference of 16.62562 secs
# [1] "tau: 1; Iteration: 10"
# Time difference of 16.11509 secs
# [1] "tau: 1; Iteration: 11"
# Time difference of 20.18478 secs
# [1] "tau: 1; Iteration: 12"
# Time difference of 9.833252 secs
# [1] "tau: 1; Iteration: 13"
# Time difference of 13.65473 secs
# [1] "tau: 1; Iteration: 14"
# Time difference of 15.59973 secs
# [1] "tau: 1; Iteration: 15"
# Time difference of 17.07773 secs
# [1] "tau: 1; Iteration: 16"
# Time difference of 14.48608 secs
# [1] "tau: 1; Iteration: 17"
# Time difference of 17.64479 secs
# [1] "tau: 1; Iteration: 18"
# Time difference of 20.66913 secs
# [1] "tau: 1; Iteration: 19"
# Time difference of 20.62106 secs
# [1] "tau: 1; Iteration: 20"
# Time difference of 14.56724 secs
# [1] "tau: 1; Iteration: 21"
# Time difference of 12.29781 secs
# [1] "tau: 1; Iteration: 22"
# Time difference of 17.33545 secs
# [1] "tau: 1; Iteration: 23"
# Time difference of 13.16848 secs
# [1] "tau: 1; Iteration: 24"
# Time difference of 17.07937 secs
# [1] "tau: 1; Iteration: 25"
# Time difference of 16.03774 secs
# [1] "tau: 1; Iteration: 26"
# Time difference of 18.73094 secs
# [1] "tau: 1; Iteration: 27"
# Time difference of 13.91668 secs
# [1] "tau: 1; Iteration: 28"
# Time difference of 11.68739 secs
# [1] "tau: 1; Iteration: 29"
# Time difference of 15.70694 secs
# [1] "tau: 1; Iteration: 30"
# Time difference of 14.31549 secs
# [1] "tau: 1; Iteration: 31"
# Time difference of 14.87151 secs
# [1] "tau: 1; Iteration: 32"
# Time difference of 19.49219 secs
# [1] "tau: 1; Iteration: 33"
# Time difference of 13.88827 secs
# [1] "tau: 1; Iteration: 34"
# Time difference of 21.24404 secs
# [1] "tau: 1; Iteration: 35"
# Time difference of 15.2614 secs
# [1] "tau: 1; Iteration: 36"
# Time difference of 16.79456 secs
# [1] "tau: 1; Iteration: 37"
# Time difference of 20.26808 secs
# [1] "tau: 1; Iteration: 38"
# Time difference of 19.70345 secs
# [1] "tau: 1; Iteration: 39"
# Time difference of 18.38567 secs
# [1] "tau: 1; Iteration: 40"
# Time difference of 17.07624 secs
# [1] "tau: 1; Iteration: 41"
# Time difference of 17.14134 secs
# [1] "tau: 1; Iteration: 42"
# Time difference of 22.25536 secs
# [1] "tau: 1; Iteration: 43"
# Time difference of 16.44938 secs
# [1] "tau: 1; Iteration: 44"
# Time difference of 18.89192 secs
# [1] "tau: 1; Iteration: 45"
# Time difference of 18.29655 secs
# [1] "tau: 1; Iteration: 46"
# Time difference of 13.82731 secs
# [1] "tau: 1; Iteration: 47"
# Time difference of 12.18745 secs
# [1] "tau: 1; Iteration: 48"
# Time difference of 18.00485 secs
# [1] "tau: 1; Iteration: 49"
# Time difference of 21.69609 secs
# [1] "tau: 1; Iteration: 50"
# Time difference of 15.72413 secs
# [1] "tau: 11; Iteration: 1"
# Time difference of 13.25277 secs
# [1] "tau: 11; Iteration: 2"
# Time difference of 18.62016 secs
# [1] "tau: 11; Iteration: 3"
# Time difference of 15.27806 secs
# [1] "tau: 11; Iteration: 4"
# Time difference of 19.93751 secs
# [1] "tau: 11; Iteration: 5"
# Time difference of 15.9247 secs
# [1] "tau: 11; Iteration: 6"
# Time difference of 17.04663 secs
# [1] "tau: 11; Iteration: 7"
# Time difference of 11.56587 secs
# [1] "tau: 11; Iteration: 8"
# Time difference of 16.45931 secs
# [1] "tau: 11; Iteration: 9"
# Time difference of 16.04363 secs
# [1] "tau: 11; Iteration: 10"
# Time difference of 14.19499 secs
# [1] "tau: 11; Iteration: 11"
# Time difference of 17.03774 secs
# [1] "tau: 11; Iteration: 12"
# Time difference of 19.45415 secs
# [1] "tau: 11; Iteration: 13"
# Time difference of 15.42053 secs
# [1] "tau: 11; Iteration: 14"
# Time difference of 11.30478 secs
# [1] "tau: 11; Iteration: 15"
# Time difference of 18.88131 secs
# [1] "tau: 11; Iteration: 16"
# Time difference of 14.72869 secs
# [1] "tau: 11; Iteration: 17"
# Time difference of 19.72825 secs
# [1] "tau: 11; Iteration: 18"
# Time difference of 18.85106 secs
# [1] "tau: 11; Iteration: 19"
# Time difference of 14.67847 secs
# [1] "tau: 11; Iteration: 20"
# Time difference of 18.35559 secs
# [1] "tau: 11; Iteration: 21"
# Time difference of 16.98108 secs
# [1] "tau: 11; Iteration: 22"
# Time difference of 13.01585 secs
# [1] "tau: 11; Iteration: 23"
# Time difference of 13.46189 secs
# [1] "tau: 11; Iteration: 24"
# Time difference of 13.43942 secs
# [1] "tau: 11; Iteration: 25"
# Time difference of 20.39318 secs
# [1] "tau: 11; Iteration: 26"
# Time difference of 21.4574 secs
# [1] "tau: 11; Iteration: 27"
# Time difference of 20.03121 secs
# [1] "tau: 11; Iteration: 28"
# Time difference of 13.16844 secs
# [1] "tau: 11; Iteration: 29"
# Time difference of 14.95593 secs
# [1] "tau: 11; Iteration: 30"
# Time difference of 15.21749 secs
# [1] "tau: 11; Iteration: 31"
# Time difference of 17.26553 secs
# [1] "tau: 11; Iteration: 32"
# Time difference of 15.69583 secs
# [1] "tau: 11; Iteration: 33"
# Time difference of 14.8682 secs
# [1] "tau: 11; Iteration: 34"
# Time difference of 15.79727 secs
# [1] "tau: 11; Iteration: 35"
# Time difference of 12.73316 secs
# [1] "tau: 11; Iteration: 36"
# Time difference of 16.34583 secs
# [1] "tau: 11; Iteration: 37"
# Time difference of 18.83104 secs
# [1] "tau: 11; Iteration: 38"
# Time difference of 19.72437 secs
# [1] "tau: 11; Iteration: 39"
# Time difference of 21.30083 secs
# [1] "tau: 11; Iteration: 40"
# Time difference of 14.89699 secs
# [1] "tau: 11; Iteration: 41"
# Time difference of 16.10057 secs
# [1] "tau: 11; Iteration: 42"
# Time difference of 19.043 secs
# [1] "tau: 11; Iteration: 43"
# Time difference of 15.86272 secs
# [1] "tau: 11; Iteration: 44"
# Time difference of 15.47117 secs
# [1] "tau: 11; Iteration: 45"
# Time difference of 14.28406 secs
# [1] "tau: 11; Iteration: 46"
# Time difference of 14.02736 secs
# [1] "tau: 11; Iteration: 47"
# Time difference of 22.68097 secs
# [1] "tau: 11; Iteration: 48"
# Time difference of 15.62006 secs
# [1] "tau: 11; Iteration: 49"
# Time difference of 15.14624 secs
# [1] "tau: 11; Iteration: 50"
# Time difference of 15.60357 secs
# [1] "tau: 16; Iteration: 1"
# Time difference of 18.70365 secs
# [1] "tau: 16; Iteration: 2"
# Time difference of 18.52501 secs
# [1] "tau: 16; Iteration: 3"
# Time difference of 14.70778 secs
# [1] "tau: 16; Iteration: 4"
# Time difference of 12.98881 secs
# [1] "tau: 16; Iteration: 5"
# Time difference of 17.81631 secs
# [1] "tau: 16; Iteration: 6"
# Time difference of 20.6202 secs
# [1] "tau: 16; Iteration: 7"
# Time difference of 16.59942 secs
# [1] "tau: 16; Iteration: 8"
# Time difference of 12.6059 secs
# [1] "tau: 16; Iteration: 9"
# Time difference of 14.47708 secs
# [1] "tau: 16; Iteration: 10"
# Time difference of 19.80656 secs
# [1] "tau: 16; Iteration: 11"
# Time difference of 13.23871 secs
# [1] "tau: 16; Iteration: 12"
# Time difference of 19.08542 secs
# [1] "tau: 16; Iteration: 13"
# Time difference of 18.74515 secs
# [1] "tau: 16; Iteration: 14"
# Time difference of 17.62094 secs
# [1] "tau: 16; Iteration: 15"
# Time difference of 17.85197 secs
# [1] "tau: 16; Iteration: 16"
# Time difference of 19.98548 secs
# [1] "tau: 16; Iteration: 17"
# Time difference of 21.71321 secs
# [1] "tau: 16; Iteration: 18"
# Time difference of 20.34614 secs
# [1] "tau: 16; Iteration: 19"
# Time difference of 14.34966 secs
# [1] "tau: 16; Iteration: 20"
# Time difference of 13.84117 secs
# [1] "tau: 16; Iteration: 21"
# Time difference of 18.38398 secs
# [1] "tau: 16; Iteration: 22"
# Time difference of 15.36618 secs
# [1] "tau: 16; Iteration: 23"
# Time difference of 17.61772 secs
# [1] "tau: 16; Iteration: 24"
# Time difference of 18.57945 secs
# [1] "tau: 16; Iteration: 25"
# Time difference of 20.28744 secs
# [1] "tau: 16; Iteration: 26"
# Time difference of 11.16636 secs
# [1] "tau: 16; Iteration: 27"
# Time difference of 15.40244 secs
# [1] "tau: 16; Iteration: 28"
# Time difference of 16.64661 secs
# [1] "tau: 16; Iteration: 29"
# Time difference of 17.29184 secs
# [1] "tau: 16; Iteration: 30"
# Time difference of 22.58206 secs
# [1] "tau: 16; Iteration: 31"
# Time difference of 14.80886 secs
# [1] "tau: 16; Iteration: 32"
# Time difference of 16.26002 secs
# [1] "tau: 16; Iteration: 33"
# Time difference of 17.66018 secs
# [1] "tau: 16; Iteration: 34"
# Time difference of 15.20976 secs
# [1] "tau: 16; Iteration: 35"
# Time difference of 19.24104 secs
# [1] "tau: 16; Iteration: 36"
# Time difference of 16.43779 secs
# [1] "tau: 16; Iteration: 37"
# Time difference of 15.41819 secs
# [1] "tau: 16; Iteration: 38"
# Time difference of 15.38852 secs
# [1] "tau: 16; Iteration: 39"
# Time difference of 12.94368 secs
# [1] "tau: 16; Iteration: 40"
# Time difference of 15.02383 secs
# [1] "tau: 16; Iteration: 41"
# Time difference of 15.21943 secs
# [1] "tau: 16; Iteration: 42"
# Time difference of 19.49225 secs
# [1] "tau: 16; Iteration: 43"
# Time difference of 18.30042 secs
# [1] "tau: 16; Iteration: 44"
# Time difference of 17.39562 secs
# [1] "tau: 16; Iteration: 45"
# Time difference of 17.08771 secs
# [1] "tau: 16; Iteration: 46"
# Time difference of 20.1925 secs
# [1] "tau: 16; Iteration: 47"
# Time difference of 19.11301 secs
# [1] "tau: 16; Iteration: 48"
# Time difference of 15.79948 secs
# [1] "tau: 16; Iteration: 49"
# Time difference of 17.36123 secs
# [1] "tau: 16; Iteration: 50"
# Time difference of 23.47422 secs
# [1] "tau: 21; Iteration: 1"
# Time difference of 14.8967 secs
# [1] "tau: 21; Iteration: 2"
# Time difference of 14.9119 secs
# [1] "tau: 21; Iteration: 3"
# Time difference of 13.14878 secs
# [1] "tau: 21; Iteration: 4"
# Time difference of 17.84391 secs
# [1] "tau: 21; Iteration: 5"
# Time difference of 15.74738 secs
# [1] "tau: 21; Iteration: 6"
# Time difference of 13.16241 secs
# [1] "tau: 21; Iteration: 7"
# Time difference of 15.05456 secs
# [1] "tau: 21; Iteration: 8"
# Time difference of 10.69262 secs
# [1] "tau: 21; Iteration: 9"
# Time difference of 16.66619 secs
# [1] "tau: 21; Iteration: 10"
# Time difference of 20.49753 secs
# [1] "tau: 21; Iteration: 11"
# Time difference of 19.8208 secs
# [1] "tau: 21; Iteration: 12"
# Time difference of 15.52079 secs
# [1] "tau: 21; Iteration: 13"
# Time difference of 15.73675 secs
# [1] "tau: 21; Iteration: 14"
# Time difference of 12.06778 secs
# [1] "tau: 21; Iteration: 15"
# Time difference of 13.2621 secs
# [1] "tau: 21; Iteration: 16"
# Time difference of 14.67497 secs
# [1] "tau: 21; Iteration: 17"
# Time difference of 17.30068 secs
# [1] "tau: 21; Iteration: 18"
# Time difference of 18.17828 secs
# [1] "tau: 21; Iteration: 19"
# Time difference of 15.62946 secs
# [1] "tau: 21; Iteration: 20"
# Time difference of 15.77226 secs
# [1] "tau: 21; Iteration: 21"
# Time difference of 17.94699 secs
# [1] "tau: 21; Iteration: 22"
# Time difference of 13.94 secs
# [1] "tau: 21; Iteration: 23"
# Time difference of 13.69017 secs
# [1] "tau: 21; Iteration: 24"
# Time difference of 19.20282 secs
# [1] "tau: 21; Iteration: 25"
# Time difference of 16.87065 secs
# [1] "tau: 21; Iteration: 26"
# Time difference of 24.3271 secs
# [1] "tau: 21; Iteration: 27"
# Time difference of 15.87688 secs
# [1] "tau: 21; Iteration: 28"
# Time difference of 20.74596 secs
# [1] "tau: 21; Iteration: 29"
# Time difference of 16.06586 secs
# [1] "tau: 21; Iteration: 30"
# Time difference of 19.80501 secs
# [1] "tau: 21; Iteration: 31"
# Time difference of 21.56014 secs
# [1] "tau: 21; Iteration: 32"
# Time difference of 13.39541 secs
# [1] "tau: 21; Iteration: 33"
# Time difference of 17.78158 secs
# [1] "tau: 21; Iteration: 34"
# Time difference of 12.56816 secs
# [1] "tau: 21; Iteration: 35"
# Time difference of 16.78975 secs
# [1] "tau: 21; Iteration: 36"
# Time difference of 18.13193 secs
# [1] "tau: 21; Iteration: 37"
# Time difference of 22.0706 secs
# [1] "tau: 21; Iteration: 38"
# Time difference of 15.84869 secs
# [1] "tau: 21; Iteration: 39"
# Time difference of 15.76385 secs
# [1] "tau: 21; Iteration: 40"
# Time difference of 15.3332 secs
# [1] "tau: 21; Iteration: 41"
# Time difference of 16.28783 secs
# [1] "tau: 21; Iteration: 42"
# Time difference of 17.04627 secs
# [1] "tau: 21; Iteration: 43"
# Time difference of 17.18207 secs
# [1] "tau: 21; Iteration: 44"
# Time difference of 15.25094 secs
# [1] "tau: 21; Iteration: 45"
# Time difference of 20.55843 secs
# [1] "tau: 21; Iteration: 46"
# Time difference of 15.68823 secs
# [1] "tau: 21; Iteration: 47"
# Time difference of 16.32232 secs
# [1] "tau: 21; Iteration: 48"
# Time difference of 14.08564 secs
# [1] "tau: 21; Iteration: 49"
# Time difference of 11.9838 secs
# [1] "tau: 21; Iteration: 50"
# Time difference of 14.38048 secs
# [1] "tau: 26; Iteration: 1"
# Time difference of 16.13669 secs
# [1] "tau: 26; Iteration: 2"
# Time difference of 17.23472 secs
# [1] "tau: 26; Iteration: 3"
# Time difference of 14.25384 secs
# [1] "tau: 26; Iteration: 4"
# Time difference of 14.07858 secs
# [1] "tau: 26; Iteration: 5"
# Time difference of 14.58917 secs
# [1] "tau: 26; Iteration: 6"
# Time difference of 16.56772 secs
# [1] "tau: 26; Iteration: 7"
# Time difference of 16.96587 secs
# [1] "tau: 26; Iteration: 8"
# Time difference of 17.89651 secs
# [1] "tau: 26; Iteration: 9"
# Time difference of 15.69524 secs
# [1] "tau: 26; Iteration: 10"
# Time difference of 14.50852 secs
# [1] "tau: 26; Iteration: 11"
# Time difference of 17.36446 secs
# [1] "tau: 26; Iteration: 12"
# Time difference of 19.71558 secs
# [1] "tau: 26; Iteration: 13"
# Time difference of 17.68901 secs
# [1] "tau: 26; Iteration: 14"
# Time difference of 12.64426 secs
# [1] "tau: 26; Iteration: 15"
# Time difference of 19.83328 secs
# [1] "tau: 26; Iteration: 16"
# Time difference of 18.34353 secs
# [1] "tau: 26; Iteration: 17"
# Time difference of 14.82205 secs
# [1] "tau: 26; Iteration: 18"
# Time difference of 15.70562 secs
# [1] "tau: 26; Iteration: 19"
# Time difference of 15.89036 secs
# [1] "tau: 26; Iteration: 20"
# Time difference of 18.93663 secs
# [1] "tau: 26; Iteration: 21"
# Time difference of 14.75781 secs
# [1] "tau: 26; Iteration: 22"
# Time difference of 21.44699 secs
# [1] "tau: 26; Iteration: 23"
# Time difference of 18.20714 secs
# [1] "tau: 26; Iteration: 24"
# Time difference of 20.92346 secs
# [1] "tau: 26; Iteration: 25"
# Time difference of 17.85866 secs
# [1] "tau: 26; Iteration: 26"
# Time difference of 20.08125 secs
# [1] "tau: 26; Iteration: 27"
# Time difference of 19.19242 secs
# [1] "tau: 26; Iteration: 28"
# Time difference of 17.97816 secs
# [1] "tau: 26; Iteration: 29"
# Time difference of 18.31407 secs
# [1] "tau: 26; Iteration: 30"
# Time difference of 19.28277 secs
# [1] "tau: 26; Iteration: 31"
# Time difference of 19.4751 secs
# [1] "tau: 26; Iteration: 32"
# Time difference of 17.15954 secs
# [1] "tau: 26; Iteration: 33"
# Time difference of 18.18217 secs
# [1] "tau: 26; Iteration: 34"
# Time difference of 21.13003 secs
# [1] "tau: 26; Iteration: 35"
# Time difference of 13.99773 secs
# [1] "tau: 26; Iteration: 36"
# Time difference of 18.67579 secs
# [1] "tau: 26; Iteration: 37"
# Time difference of 19.89291 secs
# [1] "tau: 26; Iteration: 38"
# Time difference of 13.62625 secs
# [1] "tau: 26; Iteration: 39"
# Time difference of 16.78432 secs
# [1] "tau: 26; Iteration: 40"
# Time difference of 13.22483 secs
# [1] "tau: 26; Iteration: 41"
# Time difference of 17.4599 secs
# [1] "tau: 26; Iteration: 42"
# Time difference of 18.38354 secs
# [1] "tau: 26; Iteration: 43"
# Time difference of 19.16712 secs
# [1] "tau: 26; Iteration: 44"
# Time difference of 14.85445 secs
# [1] "tau: 26; Iteration: 45"
# Time difference of 18.17128 secs
# [1] "tau: 26; Iteration: 46"
# Time difference of 19.12881 secs
# [1] "tau: 26; Iteration: 47"
# Time difference of 16.57605 secs
# [1] "tau: 26; Iteration: 48"
# Time difference of 14.7882 secs
# [1] "tau: 26; Iteration: 49"
# Time difference of 20.32115 secs
# [1] "tau: 26; Iteration: 50"
# Time difference of 19.25385 secs

# %%
tauRMSEDataForLatex <- aggTauData %>% mutate(
    `RMSE (SE)` = paste(round(RMSE, 3), ' (', round(SE, 3), ')', sep='')) 

tauRMSEDataForLatex <- tauRMSEDataForLatex[c('Method', 'RMSE (SE)', 'Tau')]

tauRMSEDataForLatex <- spread(tauRMSEDataForLatex, key=Tau, value=`RMSE (SE)`) 

tauRMSEDataForLatex<- knitr::kable(tauRMSEDataForLatex, 'latex')

# %% [markdown]
# # Influence True Rank on Performance

# %%
#all_ranks <- seq(2, 20, 2)



#all_ranks <- c(5, 8, 12, 16, 20)

all_ranks <- c(3,5,7,9,11)

msesRankData <- array(NA, dim=c(length(methodNames), draws_per_L, length(all_ranks) ),
                   dimnames=c(list(Method=methodNames), list(Iteration=1:draws_per_L), list(Rank=all_ranks)))

for (rank in all_ranks){
    
  rankForIndex <- as.character(rank)
  
  set.seed(3729)
  
  if (design=="staggered_adoption"){ ## Come up with a way to vary the lag in the staggered structure
  
  if(lag_structure == "random"){
    
    ones_we_make <- c(rep(0, N0), pmin(rpois(N-N0, 
                                            lambda=average_treatment_length-1)+1, 
                                      min(max_lag*(N-N0), .8*Time)))
    
  }else if (lag_structure=="constant"){ ## Does not control T-T0
    
    ones_we_make <- c(rep(0, N0), pmin(max_lag*seq(1, (N-N0)), floor(.8*Time)))
    
  }

}else if (design=="simultaneous_adoption"){
  
  ones_we_make <- c(rep(0, N0), rep(Time-Time0, N-N0))
  
}

  W <- W_maker(N=N, Time=Time, ones_per_row = ones_we_make)

  tau_matrix <- t(apply(W, MARGIN=1, FUN=treated_matrix_creator, 
                      f_of_t=treatment_function, arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff))

  treated_units <- as.numeric(which(apply(W, MARGIN=1, FUN = function(x) any(x==1))))
  
  treatment_times <- as.numeric(which(apply(W, MARGIN=2, FUN = function(x) any(x==1))))

  delta_t <- treatment_function(treatment_times-(min(treatment_times)-1),
                              arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff, value=tau)
  
  prediction_error_matrix_did <- matrix(NA, nrow=number_of_L, ncol=draws_per_L)
  
  prediction_error_matrix_sc <- matrix(NA, nrow=number_of_L, ncol=draws_per_L)                                    
                                            
  prediction_error_matrix_mc_nnm <- matrix(NA, nrow=number_of_L, ncol=draws_per_L)

  prediction_error_matrix_sdid <- matrix(NA, nrow=number_of_L, ncol=draws_per_L)

  prediction_error_matrix_lapis <- matrix(NA, nrow=number_of_L, ncol=draws_per_L)
  
  prediction_error_matrix_oracle <- matrix(NA, nrow=number_of_L, ncol=draws_per_L)
  
  autocorrelation_matrix <- make_rho_mat(rho=rho_parameter, p=dim(W)[2])
  
for (i in 1:number_of_L){
    
    if (balanced){
      
      U_vec <- rexp(n=N*rank, rate=1)
  
      V_vec <- rexp(n=Time*rank, rate=1)
    
      U <- matrix(U_vec, nrow=N, ncol=rank, byrow=T)
  
      V <- matrix(V_vec, nrow=Time, ncol=rank, byrow=T)
    
    }else{
      
      U <- matrix(NA, nrow=N, ncol=rank, byrow=T)
  
      V <- matrix(NA, nrow=Time, ncol=rank, byrow=T)
      
      for (row_unit in 1:N){
        
        U[row_unit,] <- rpois(n=rank, lambda=sqrt(row_unit/N))
        
      } 
      
      for (row_time in 1:Time){
        
        V[row_time,] <- rpois(n=rank, lambda=sqrt(row_time/Time))
        
      }
      
    }
  
    L <- L_scaling*(U %*% t(V))
    
    for (j in 1:draws_per_L){
        
      startTime <- Sys.time()
      
      if (error == 'gaussian'){
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+tau*W, distribution='gaussian',
                   scalar_sigma=sqrt(sigma_squared))
        
      } else if (error == 't'){
      
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+tau*W,
                   distribution='t', scalar_sigma=sqrt(sigma_squared))
      
      } else if (error == 'poisson'){
        
        if (balanced == F){
        
          L <- abs(L)+1
          
        }
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+tau*W,
                   distribution='poisson', scalar_sigma=sqrt(sigma_squared))
        
      } else if (error == 'scaled_gamma'){
        
        if (balanced == F){
        
          L <- abs(L)+1
          
        }
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+tau*W,
                   distribution='scaled_gamma', scalar_sigma=sqrt(sigma_squared))
        
      }else if (error == 'exponential'){
        
        if (balanced == F){
        
          L <- abs(L)+1
          
        }
        
        Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                   desired_mean_matrix= L+tau*W,
                   distribution='exponential', scalar_sigma=sqrt(sigma_squared))
  
      }
      
      #estimated_rank <- rank_estimator(Y, W, num_iter=100, K=5, 
      #                      lambda_grid=c(0, 10^seq(-20, 0, 2)), 
      #                      method="threshold")
      
      #Y_0_LAPIS <- LAPIS(Y, rank_threshold=estimated_rank,
      #                                    min_iter=1, max_iter=max_iter,
      #                                    tolerance=tolerance, W=W)
      
      
      if (N-N0 > 1){
      
      treatment_subjects_averaged <- colMeans(Y[1:dim(Y)[1] > N0,])
      
      W_averaged <- colMeans(W[1:dim(W)[1] > N0,])
      
      new_Y <- rbind(Y[1:dim(Y)[1] <= N0,], treatment_subjects_averaged)
      
      new_W <- rbind(W[1:dim(Y)[1] <= N0,], W_averaged)
      
      } else {
      
        new_Y <- Y
      
        new_W <- W
        
        
      }
      
      tau_estimate_did <- DID(Y=Y, W=W)
      
      tau_estimate_sc <- synth_cont(Y=Y, W=W)


      tau_estimate_sdid <- SDID_general(Y=Y, W=W,
                   iterations_for_coord_desc=100)
      
    mc_nnm_info <- matrix_completion_causal(Y=Y, W=W, num_iter=1000, K=5, 
                            lambda_grid=c(10^seq(-4,2,1), seq(2,5,1)),
                            tol=1e-04)
    
    L_mc_nnm <- mc_nnm_info$L_hat
    
    tau_estimate_mc_nnm <- treat.estimator(Y=Y, L.hat=L_mc_nnm, W=W)
        
    estFactors <- rankMatrix(mc_nnm_info$L_hat)[1]  
    
    lapis_info <- LAPIS_with_rank_estimation(Y=Y, 
                           W=W, initial_rank=rankMatrix(mc_nnm_info$L_hat)[1],
                           tolerance=tolerance, 
                           min_iter=min_iter, max_iter=max_iter,   
                           mu_grid=NULL, warm_start=F, method = 'explicit_tau')
      
    tau_estimate_lapis <- treat.estimator(Y, lapis_info, W)
    
    tau_estimate_oracle <- treat.estimator(Y=Y, L.hat=L, W=W)
    
    ## Only oracle in the sense that we know L

  
      msesRankData['DID', j, rankForIndex] <- mean(abs(tau_estimate_did-delta_t)^2)
    
      msesRankData['SC', j, rankForIndex] <- mean(abs(tau_estimate_sc-delta_t)^2)
    
      msesRankData['MC-NNM', j, rankForIndex] <- mean(abs(tau_estimate_mc_nnm-delta_t)^2)
    
      msesRankData['SDID', j, rankForIndex] <- mean(abs(tau_estimate_sdid-delta_t)^2)
    
      msesRankData['LAPIS', j, rankForIndex] <- mean(abs(tau_estimate_lapis-delta_t)^2)
    
      msesRankData['ORACLE', j, rankForIndex] <- mean(abs(tau_estimate_oracle-delta_t)^2)
    
      endTime <- Sys.time()
        
      outMessage <- paste('rank: ', rank, '; Iteration: ', j, sep='')
      
      print(outMessage)
      
      print(difftime(endTime, startTime, 'mins'))
  
    }

}

}
                                          
meltedRankData <- as_tibble(as.tbl_cube(msesRankData, met='MSE'))
                                            
meltedRankData$Method <- factor(meltedRankData$Method, levels=methodNames)      
                                            
meltedRankData <- meltedRankData  %>% filter(Method !='DID') 
 
aggRankData <- meltedRankData %>% group_by(Method, Rank) %>% dplyr::summarize(RMSE = mean(sqrt(MSE)),
                                                                SE = sd(sqrt(MSE))/sqrt(n()))

p_mse_vs_rank <- (ggplot(aggRankData, aes(x=Rank, y=RMSE, col=Method)) + geom_line(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of the Rank of L") + xlab("Rank of L") )
                                            
p_mse_vs_rank_uncertainty <- (ggplot(meltedRankData, aes(x=Rank, y=sqrt(MSE), col=Method)) + geom_smooth(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of the Rank of L")  + xlab("Rank of L") )
# Out:
# [1] "rank: 3; Iteration: 1"
# Time difference of 11.62336 secs
# [1] "rank: 3; Iteration: 2"
# Time difference of 9.441652 secs
# [1] "rank: 3; Iteration: 3"
# Time difference of 11.8351 secs
# [1] "rank: 3; Iteration: 4"
# Time difference of 10.40649 secs
# [1] "rank: 3; Iteration: 5"
# Time difference of 13.16339 secs
# [1] "rank: 3; Iteration: 6"
# Time difference of 10.53866 secs
# [1] "rank: 3; Iteration: 7"
# Time difference of 9.220143 secs
# [1] "rank: 3; Iteration: 8"
# Time difference of 11.08233 secs
# [1] "rank: 3; Iteration: 9"
# Time difference of 12.04223 secs
# [1] "rank: 3; Iteration: 10"
# Time difference of 11.85517 secs
# [1] "rank: 3; Iteration: 11"
# Time difference of 8.952543 secs
# [1] "rank: 3; Iteration: 12"
# Time difference of 14.24373 secs
# [1] "rank: 3; Iteration: 13"
# Time difference of 11.8698 secs
# [1] "rank: 3; Iteration: 14"
# Time difference of 11.89576 secs
# [1] "rank: 3; Iteration: 15"
# Time difference of 12.72717 secs
# [1] "rank: 3; Iteration: 16"
# Time difference of 10.91949 secs
# [1] "rank: 3; Iteration: 17"
# Time difference of 12.07053 secs
# [1] "rank: 3; Iteration: 18"
# Time difference of 11.99964 secs
# [1] "rank: 3; Iteration: 19"
# Time difference of 11.02466 secs
# [1] "rank: 3; Iteration: 20"
# Time difference of 11.97181 secs
# [1] "rank: 3; Iteration: 21"
# Time difference of 12.30062 secs
# [1] "rank: 3; Iteration: 22"
# Time difference of 11.37606 secs
# [1] "rank: 3; Iteration: 23"
# Time difference of 12.24207 secs
# [1] "rank: 3; Iteration: 24"
# Time difference of 13.84275 secs
# [1] "rank: 3; Iteration: 25"
# Time difference of 11.14059 secs
# [1] "rank: 3; Iteration: 26"
# Time difference of 10.154 secs
# [1] "rank: 3; Iteration: 27"
# Time difference of 11.74115 secs
# [1] "rank: 3; Iteration: 28"
# Time difference of 12.18033 secs
# [1] "rank: 3; Iteration: 29"
# Time difference of 12.67434 secs
# [1] "rank: 3; Iteration: 30"
# Time difference of 13.15451 secs
# [1] "rank: 3; Iteration: 31"
# Time difference of 10.43769 secs
# [1] "rank: 3; Iteration: 32"
# Time difference of 11.54759 secs
# [1] "rank: 3; Iteration: 33"
# Time difference of 9.983681 secs
# [1] "rank: 3; Iteration: 34"
# Time difference of 12.66199 secs
# [1] "rank: 3; Iteration: 35"
# Time difference of 10.04244 secs
# [1] "rank: 3; Iteration: 36"
# Time difference of 9.493201 secs
# [1] "rank: 3; Iteration: 37"
# Time difference of 9.025456 secs
# [1] "rank: 3; Iteration: 38"
# Time difference of 11.56317 secs
# [1] "rank: 3; Iteration: 39"
# Time difference of 11.0907 secs
# [1] "rank: 3; Iteration: 40"
# Time difference of 8.607639 secs
# [1] "rank: 3; Iteration: 41"
# Time difference of 11.8845 secs
# [1] "rank: 3; Iteration: 42"
# Time difference of 12.55269 secs
# [1] "rank: 3; Iteration: 43"
# Time difference of 11.14925 secs
# [1] "rank: 3; Iteration: 44"
# Time difference of 10.21956 secs
# [1] "rank: 3; Iteration: 45"
# Time difference of 11.62819 secs
# [1] "rank: 3; Iteration: 46"
# Time difference of 12.42807 secs
# [1] "rank: 3; Iteration: 47"
# Time difference of 12.31043 secs
# [1] "rank: 3; Iteration: 48"
# Time difference of 14.64436 secs
# [1] "rank: 3; Iteration: 49"
# Time difference of 11.07437 secs
# [1] "rank: 3; Iteration: 50"
# Time difference of 8.969364 secs
# [1] "rank: 5; Iteration: 1"
# Time difference of 13.23314 secs
# [1] "rank: 5; Iteration: 2"
# Time difference of 12.34773 secs
# [1] "rank: 5; Iteration: 3"
# Time difference of 13.51171 secs
# [1] "rank: 5; Iteration: 4"
# Time difference of 12.24372 secs
# [1] "rank: 5; Iteration: 5"
# Time difference of 10.44301 secs
# [1] "rank: 5; Iteration: 6"
# Time difference of 10.73514 secs
# [1] "rank: 5; Iteration: 7"
# Time difference of 13.68158 secs
# [1] "rank: 5; Iteration: 8"
# Time difference of 20.71967 secs
# [1] "rank: 5; Iteration: 9"
# Time difference of 15.83087 secs
# [1] "rank: 5; Iteration: 10"
# Time difference of 14.87318 secs
# [1] "rank: 5; Iteration: 11"
# Time difference of 17.52904 secs
# [1] "rank: 5; Iteration: 12"
# Time difference of 11.58177 secs
# [1] "rank: 5; Iteration: 13"
# Time difference of 15.35666 secs
# [1] "rank: 5; Iteration: 14"
# Time difference of 11.49263 secs
# [1] "rank: 5; Iteration: 15"
# Time difference of 12.73722 secs
# [1] "rank: 5; Iteration: 16"
# Time difference of 12.77415 secs
# [1] "rank: 5; Iteration: 17"
# Time difference of 13.51416 secs
# [1] "rank: 5; Iteration: 18"
# Time difference of 12.71386 secs
# [1] "rank: 5; Iteration: 19"
# Time difference of 13.86644 secs
# [1] "rank: 5; Iteration: 20"
# Time difference of 11.37152 secs
# [1] "rank: 5; Iteration: 21"
# Time difference of 12.69359 secs
# [1] "rank: 5; Iteration: 22"
# Time difference of 17.73538 secs
# [1] "rank: 5; Iteration: 23"
# Time difference of 12.76889 secs
# [1] "rank: 5; Iteration: 24"
# Time difference of 16.46405 secs
# [1] "rank: 5; Iteration: 25"
# Time difference of 12.72923 secs
# [1] "rank: 5; Iteration: 26"
# Time difference of 15.95725 secs
# [1] "rank: 5; Iteration: 27"
# Time difference of 17.81338 secs
# [1] "rank: 5; Iteration: 28"
# Time difference of 17.69268 secs
# [1] "rank: 5; Iteration: 29"
# Time difference of 14.60349 secs
# [1] "rank: 5; Iteration: 30"
# Time difference of 17.67872 secs
# [1] "rank: 5; Iteration: 31"
# Time difference of 11.39084 secs
# [1] "rank: 5; Iteration: 32"
# Time difference of 20.27029 secs
# [1] "rank: 5; Iteration: 33"
# Time difference of 12.97237 secs
# [1] "rank: 5; Iteration: 34"
# Time difference of 17.80392 secs
# [1] "rank: 5; Iteration: 35"
# Time difference of 14.58521 secs
# [1] "rank: 5; Iteration: 36"
# Time difference of 17.73965 secs
# [1] "rank: 5; Iteration: 37"
# Time difference of 15.35407 secs
# [1] "rank: 5; Iteration: 38"
# Time difference of 13.68221 secs
# [1] "rank: 5; Iteration: 39"
# Time difference of 15.01296 secs
# [1] "rank: 5; Iteration: 40"
# Time difference of 14.99912 secs
# [1] "rank: 5; Iteration: 41"
# Time difference of 14.44064 secs
# [1] "rank: 5; Iteration: 42"
# Time difference of 13.55725 secs
# [1] "rank: 5; Iteration: 43"
# Time difference of 18.28296 secs
# [1] "rank: 5; Iteration: 44"
# Time difference of 14.57387 secs
# [1] "rank: 5; Iteration: 45"
# Time difference of 13.93921 secs
# [1] "rank: 5; Iteration: 46"
# Time difference of 20.25657 secs
# [1] "rank: 5; Iteration: 47"
# Time difference of 12.91406 secs
# [1] "rank: 5; Iteration: 48"
# Time difference of 14.0498 secs
# [1] "rank: 5; Iteration: 49"
# Time difference of 13.45764 secs
# [1] "rank: 5; Iteration: 50"
# Time difference of 20.17413 secs
# [1] "rank: 7; Iteration: 1"
# Time difference of 12.91773 secs
# [1] "rank: 7; Iteration: 2"
# Time difference of 12.24044 secs
# [1] "rank: 7; Iteration: 3"
# Time difference of 12.17085 secs
# [1] "rank: 7; Iteration: 4"
# Time difference of 16.52776 secs
# [1] "rank: 7; Iteration: 5"
# Time difference of 13.11556 secs
# [1] "rank: 7; Iteration: 6"
# Time difference of 12.83336 secs
# [1] "rank: 7; Iteration: 7"
# Time difference of 10.02727 secs
# [1] "rank: 7; Iteration: 8"
# Time difference of 15.90376 secs
# [1] "rank: 7; Iteration: 9"
# Time difference of 16.15396 secs
# [1] "rank: 7; Iteration: 10"
# Time difference of 18.37721 secs
# [1] "rank: 7; Iteration: 11"
# Time difference of 12.5956 secs
# [1] "rank: 7; Iteration: 12"
# Time difference of 17.71076 secs
# [1] "rank: 7; Iteration: 13"
# Time difference of 18.44995 secs
# [1] "rank: 7; Iteration: 14"
# Time difference of 17.02226 secs
# [1] "rank: 7; Iteration: 15"
# Time difference of 14.76354 secs
# [1] "rank: 7; Iteration: 16"
# Time difference of 12.24803 secs
# [1] "rank: 7; Iteration: 17"
# Time difference of 14.90247 secs
# [1] "rank: 7; Iteration: 18"
# Time difference of 17.25659 secs
# [1] "rank: 7; Iteration: 19"
# Time difference of 16.69905 secs
# [1] "rank: 7; Iteration: 20"
# Time difference of 12.28774 secs
# [1] "rank: 7; Iteration: 21"
# Time difference of 15.9929 secs
# [1] "rank: 7; Iteration: 22"
# Time difference of 15.78973 secs
# [1] "rank: 7; Iteration: 23"
# Time difference of 16.08636 secs
# [1] "rank: 7; Iteration: 24"
# Time difference of 13.55217 secs
# [1] "rank: 7; Iteration: 25"
# Time difference of 14.8893 secs
# [1] "rank: 7; Iteration: 26"
# Time difference of 12.56895 secs
# [1] "rank: 7; Iteration: 27"
# Time difference of 18.52487 secs
# [1] "rank: 7; Iteration: 28"
# Time difference of 14.44839 secs
# [1] "rank: 7; Iteration: 29"
# Time difference of 13.36807 secs
# [1] "rank: 7; Iteration: 30"
# Time difference of 20.04235 secs
# [1] "rank: 7; Iteration: 31"
# Time difference of 14.33214 secs
# [1] "rank: 7; Iteration: 32"
# Time difference of 16.16586 secs
# [1] "rank: 7; Iteration: 33"
# Time difference of 10.20711 secs
# [1] "rank: 7; Iteration: 34"
# Time difference of 11.58851 secs
# [1] "rank: 7; Iteration: 35"
# Time difference of 14.97894 secs
# [1] "rank: 7; Iteration: 36"
# Time difference of 16.66281 secs
# [1] "rank: 7; Iteration: 37"
# Time difference of 15.71119 secs
# [1] "rank: 7; Iteration: 38"
# Time difference of 11.02791 secs
# [1] "rank: 7; Iteration: 39"
# Time difference of 14.92724 secs
# [1] "rank: 7; Iteration: 40"
# Time difference of 11.18744 secs
# [1] "rank: 7; Iteration: 41"
# Time difference of 16.0005 secs
# [1] "rank: 7; Iteration: 42"
# Time difference of 16.08744 secs
# [1] "rank: 7; Iteration: 43"
# Time difference of 13.70123 secs
# [1] "rank: 7; Iteration: 44"
# Time difference of 13.04948 secs
# [1] "rank: 7; Iteration: 45"
# Time difference of 12.78291 secs
# [1] "rank: 7; Iteration: 46"
# Time difference of 18.73335 secs
# [1] "rank: 7; Iteration: 47"
# Time difference of 14.11191 secs
# [1] "rank: 7; Iteration: 48"
# Time difference of 16.21982 secs
# [1] "rank: 7; Iteration: 49"
# Time difference of 12.70237 secs
# [1] "rank: 7; Iteration: 50"
# Time difference of 15.28537 secs
# [1] "rank: 9; Iteration: 1"
# Time difference of 19.4279 secs
# [1] "rank: 9; Iteration: 2"
# Time difference of 13.99291 secs
# [1] "rank: 9; Iteration: 3"
# Time difference of 18.17937 secs
# [1] "rank: 9; Iteration: 4"
# Time difference of 17.23837 secs
# [1] "rank: 9; Iteration: 5"
# Time difference of 14.78766 secs
# [1] "rank: 9; Iteration: 6"
# Time difference of 21.06843 secs
# [1] "rank: 9; Iteration: 7"
# Time difference of 14.69349 secs
# [1] "rank: 9; Iteration: 8"
# Time difference of 14.03165 secs
# [1] "rank: 9; Iteration: 9"
# Time difference of 14.75634 secs
# [1] "rank: 9; Iteration: 10"
# Time difference of 17.93112 secs
# [1] "rank: 9; Iteration: 11"
# Time difference of 20.92058 secs
# [1] "rank: 9; Iteration: 12"
# Time difference of 15.24482 secs
# [1] "rank: 9; Iteration: 13"
# Time difference of 18.06185 secs
# [1] "rank: 9; Iteration: 14"
# Time difference of 19.64724 secs
# [1] "rank: 9; Iteration: 15"
# Time difference of 15.92473 secs
# [1] "rank: 9; Iteration: 16"
# Time difference of 17.42391 secs
# [1] "rank: 9; Iteration: 17"
# Time difference of 17.22439 secs
# [1] "rank: 9; Iteration: 18"
# Time difference of 17.75862 secs
# [1] "rank: 9; Iteration: 19"
# Time difference of 16.32572 secs
# [1] "rank: 9; Iteration: 20"
# Time difference of 16.83443 secs
# [1] "rank: 9; Iteration: 21"
# Time difference of 18.8656 secs
# [1] "rank: 9; Iteration: 22"
# Time difference of 18.98052 secs
# [1] "rank: 9; Iteration: 23"
# Time difference of 12.98845 secs
# [1] "rank: 9; Iteration: 24"
# Time difference of 15.50067 secs
# [1] "rank: 9; Iteration: 25"
# Time difference of 17.90724 secs
# [1] "rank: 9; Iteration: 26"
# Time difference of 17.40501 secs
# [1] "rank: 9; Iteration: 27"
# Time difference of 16.05514 secs
# [1] "rank: 9; Iteration: 28"
# Time difference of 15.14265 secs
# [1] "rank: 9; Iteration: 29"
# Time difference of 24.05277 secs
# [1] "rank: 9; Iteration: 30"
# Time difference of 22.66142 secs
# [1] "rank: 9; Iteration: 31"
# Time difference of 14.52663 secs
# [1] "rank: 9; Iteration: 32"
# Time difference of 11.48594 secs
# [1] "rank: 9; Iteration: 33"
# Time difference of 20.64787 secs
# [1] "rank: 9; Iteration: 34"
# Time difference of 14.6025 secs
# [1] "rank: 9; Iteration: 35"
# Time difference of 14.64754 secs
# [1] "rank: 9; Iteration: 36"
# Time difference of 16.4331 secs
# [1] "rank: 9; Iteration: 37"
# Time difference of 18.96857 secs
# [1] "rank: 9; Iteration: 38"
# Time difference of 18.03943 secs
# [1] "rank: 9; Iteration: 39"
# Time difference of 19.88529 secs
# [1] "rank: 9; Iteration: 40"
# Time difference of 12.55417 secs
# [1] "rank: 9; Iteration: 41"
# Time difference of 19.39588 secs
# [1] "rank: 9; Iteration: 42"
# Time difference of 18.40116 secs
# [1] "rank: 9; Iteration: 43"
# Time difference of 17.61052 secs
# [1] "rank: 9; Iteration: 44"
# Time difference of 14.49821 secs
# [1] "rank: 9; Iteration: 45"
# Time difference of 13.0879 secs
# [1] "rank: 9; Iteration: 46"
# Time difference of 18.43958 secs
# [1] "rank: 9; Iteration: 47"
# Time difference of 16.77938 secs
# [1] "rank: 9; Iteration: 48"
# Time difference of 12.60265 secs
# [1] "rank: 9; Iteration: 49"
# Time difference of 18.11688 secs
# [1] "rank: 9; Iteration: 50"
# Time difference of 17.4719 secs
# [1] "rank: 11; Iteration: 1"
# Time difference of 18.18901 secs
# [1] "rank: 11; Iteration: 2"
# Time difference of 16.29524 secs
# [1] "rank: 11; Iteration: 3"
# Time difference of 15.62084 secs
# [1] "rank: 11; Iteration: 4"
# Time difference of 19.60267 secs
# [1] "rank: 11; Iteration: 5"
# Time difference of 19.51676 secs
# [1] "rank: 11; Iteration: 6"
# Time difference of 21.72079 secs
# [1] "rank: 11; Iteration: 7"
# Time difference of 12.19445 secs
# [1] "rank: 11; Iteration: 8"
# Time difference of 17.86362 secs
# [1] "rank: 11; Iteration: 9"
# Time difference of 16.45549 secs
# [1] "rank: 11; Iteration: 10"
# Time difference of 15.34978 secs
# [1] "rank: 11; Iteration: 11"
# Time difference of 21.327 secs
# [1] "rank: 11; Iteration: 12"
# Time difference of 20.31111 secs
# [1] "rank: 11; Iteration: 13"
# Time difference of 19.75601 secs
# [1] "rank: 11; Iteration: 14"
# Time difference of 24.26942 secs
# [1] "rank: 11; Iteration: 15"
# Time difference of 19.49722 secs
# [1] "rank: 11; Iteration: 16"
# Time difference of 19.1187 secs
# [1] "rank: 11; Iteration: 17"
# Time difference of 16.0036 secs
# [1] "rank: 11; Iteration: 18"
# Time difference of 16.26165 secs
# [1] "rank: 11; Iteration: 19"
# Time difference of 19.00564 secs
# [1] "rank: 11; Iteration: 20"
# Time difference of 16.51585 secs
# [1] "rank: 11; Iteration: 21"
# Time difference of 19.30819 secs
# [1] "rank: 11; Iteration: 22"
# Time difference of 15.24463 secs
# [1] "rank: 11; Iteration: 23"
# Time difference of 22.7 secs
# [1] "rank: 11; Iteration: 24"
# Time difference of 19.4594 secs
# [1] "rank: 11; Iteration: 25"
# Time difference of 20.73705 secs
# [1] "rank: 11; Iteration: 26"
# Time difference of 10.38554 secs
# [1] "rank: 11; Iteration: 27"
# Time difference of 14.3104 secs
# [1] "rank: 11; Iteration: 28"
# Time difference of 22.65874 secs
# [1] "rank: 11; Iteration: 29"
# Time difference of 17.71218 secs
# [1] "rank: 11; Iteration: 30"
# Time difference of 15.39475 secs
# [1] "rank: 11; Iteration: 31"
# Time difference of 18.89574 secs
# [1] "rank: 11; Iteration: 32"
# Time difference of 17.85935 secs
# [1] "rank: 11; Iteration: 33"
# Time difference of 18.708 secs
# [1] "rank: 11; Iteration: 34"
# Time difference of 17.83988 secs
# [1] "rank: 11; Iteration: 35"
# Time difference of 16.3306 secs
# [1] "rank: 11; Iteration: 36"
# Time difference of 14.18818 secs
# [1] "rank: 11; Iteration: 37"
# Time difference of 16.77078 secs
# [1] "rank: 11; Iteration: 38"
# Time difference of 11.83944 secs
# [1] "rank: 11; Iteration: 39"
# Time difference of 19.90159 secs
# [1] "rank: 11; Iteration: 40"
# Time difference of 19.82392 secs
# [1] "rank: 11; Iteration: 41"
# Time difference of 20.32092 secs
# [1] "rank: 11; Iteration: 42"
# Time difference of 18.21057 secs
# [1] "rank: 11; Iteration: 43"
# Time difference of 19.54156 secs
# [1] "rank: 11; Iteration: 44"
# Time difference of 15.50311 secs
# [1] "rank: 11; Iteration: 45"
# Time difference of 15.11221 secs
# [1] "rank: 11; Iteration: 46"
# Time difference of 19.64071 secs
# [1] "rank: 11; Iteration: 47"
# Time difference of 14.28474 secs
# [1] "rank: 11; Iteration: 48"
# Time difference of 13.82898 secs
# [1] "rank: 11; Iteration: 49"
# Time difference of 16.62177 secs
# [1] "rank: 11; Iteration: 50"
# Time difference of 15.29296 secs

# %%
rankRMSEDataForLatex <- aggRankData %>% mutate(
    `RMSE (SE)` = paste(round(RMSE, 3), ' (', round(SE, 3), ')', sep='')) 

rankRMSEDataForLatex <- rankRMSEDataForLatex[c('Method', 'RMSE (SE)', 'Rank')]

rankRMSEDataForLatex <- spread(rankRMSEDataForLatex, key=Rank, value=`RMSE (SE)`)

rankRMSEDataForLatex <- knitr::kable(rankRMSEDataForLatex, 'latex')

# %% [markdown]
# # Influence of Rank Error on Performance

# %%
all_rank_errors <- c(-9, -5, 1, 3, 7)


msesRankErrorData <- array(NA, dim=c(length(methodNames), draws_per_L, length(all_rank_errors) ),
                   dimnames=c(list(Method=methodNames), list(Iteration=1:draws_per_L), list(Rank_error=all_rank_errors)))


for (rank_error in all_rank_errors){
  
  rankErrorForIndex <- as.character(rank_error)
  
  set.seed(3729)
  
  if (design=="staggered_adoption"){ ## Come up with a way to vary the lag in the staggered structure
  
  if(lag_structure == "random"){
    
    ones_we_make <- c(rep(0, N0), pmin(rpois(N-N0, 
                                            lambda=average_treatment_length-1)+1, 
                                      min(max_lag*(N-N0), .8*Time)))
    
  }else if (lag_structure=="constant"){ ## Does not control T-T0
    
    ones_we_make <- c(rep(0, N0), pmin(max_lag*seq(1, (N-N0)), floor(.8*Time)))
    
  }

}else if (design=="simultaneous_adoption"){
  
  ones_we_make <- c(rep(0, N0), rep(Time-Time0, N-N0))
  
}

  W <- W_maker(N=N, Time=Time, ones_per_row = ones_we_make)

  tau_matrix <- t(apply(W, MARGIN=1, FUN=treated_matrix_creator, 
                      f_of_t=treatment_function, arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff))

  treated_units <- as.numeric(which(apply(W, MARGIN=1, FUN = function(x) any(x==1))))
  
  treatment_times <- as.numeric(which(apply(W, MARGIN=2, FUN = function(x) any(x==1))))

  delta_t <- treatment_function(treatment_times-(min(treatment_times)-1),
                              arg_max=arg_max, 
                      y_max=y_max, halfway_time=halfway_time, cutoff=cutoff)
  
  autocorrelation_matrix <- make_rho_mat(rho=rho_parameter, p=dim(W)[2])
  
  for (i in 1:number_of_L){
    
    if (balanced){
      
      U_vec <- rexp(n=N*R, rate=1)
  
      V_vec <- rexp(n=Time*R, rate=1)
    
      U <- matrix(U_vec, nrow=N, ncol=R, byrow=T)
  
      V <- matrix(V_vec, nrow=Time, ncol=R, byrow=T)
    
    }else{
      
      U <- matrix(NA, nrow=N, ncol=R, byrow=T)
  
      V <- matrix(NA, nrow=Time, ncol=R, byrow=T)
      
      for (row_unit in 1:N){
        
        U[row_unit,] <- rpois(n=R, lambda=sqrt(row_unit/N))
        
      } 
      
      for (row_time in 1:Time){
        
        V[row_time,] <- rpois(n=R, lambda=sqrt(row_time/Time))
        
      }
      
    }
  
    L <- L_scaling*(U %*% t(V))
    
    for (j in 1:draws_per_L){
        
      startTime <- Sys.time()
      
        if (error == 'gaussian'){
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W, distribution='gaussian',
                 scalar_sigma=sqrt(sigma_squared))
      
    } else if (error == 't'){
    
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='t', scalar_sigma=1, df=df)
    
    } else if (error == 'poisson'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='poisson', scalar_sigma=1)
      
    } else if (error == 'scaled_gamma'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='scaled_gamma', scalar_sigma=1)
      
    }else if (error == 'exponential'){
      
      if (balanced == F){
      
        L <- abs(L)+1
        
      }
      
      Y <- norta(number=N, corr_mat=autocorrelation_matrix,
                 desired_mean_matrix= L+tau_matrix*W,
                 distribution='exponential', scalar_sigma=1)

    }
      
   # estimated_rank <- rank_estimator(Y, W, num_iter=100, K=5, 
  #                        lambda_grid=c(0, 10^seq(-20, 0, 2)), 
  #                        method="threshold")
      # estimated_rank <- rank_estimator(Y, W, num_iter=100, K=5, 
    #                      lambda_grid=c(0, 10^seq(-20, 0, 2)), 
    #                      method="threshold")
      
      
    if (N-N0 > 1){
    
      treatment_subjects_averaged <- colMeans(Y[1:dim(Y)[1] > N0,])
    
      W_averaged <- colMeans(W[1:dim(W)[1] > N0,])
    
      new_Y <- rbind(Y[1:dim(Y)[1] <= N0,], treatment_subjects_averaged)
    
      new_W <- rbind(W[1:dim(Y)[1] <= N0,], W_averaged)
    
    } else {
    
      new_Y <- Y
    
      new_W <- W
      
      
    }
    
    tau_estimate_did <- DID(Y=Y, W=W)
    
    tau_estimate_sc <- synth_cont(Y=Y, W=W)

    tau_estimate_sdid <- SDID_general(Y=Y, W=W,
                 iterations_for_coord_desc=100)
    
    mc_nnm_info <- matrix_completion_causal(Y=Y, W=W, num_iter=1000, K=5, 
                            lambda_grid=c(10^seq(-4,2,1), seq(2,5,1)),
                            tol=1e-04)
    
    L_mc_nnm <- mc_nnm_info$L_hat
    
    tau_estimate_mc_nnm <- treat.estimator(Y=Y, L.hat=L_mc_nnm, W=W)
    
        
    estFactors <- rankMatrix(mc_nnm_info$L_hat)[1]  
    
    lapis_info <- LAPIS_with_rank_estimation(Y=Y, 
                           W=W, initial_rank=R+rank_error,
                           tolerance=tolerance, 
                           min_iter=min_iter, max_iter=max_iter,   
                           mu_grid=NULL, warm_start=F, method = 'explicit_tau')
      
      
    tau_estimate_lapis <- treat.estimator(Y, lapis_info, W)
    
    tau_estimate_oracle <- treat.estimator(Y=Y, L.hat=L, W=W)
    
    
    # tau_estimate_mc_nnm
    
    ## Only oracle in the sense that we know L
    
      msesRankErrorData['DID', j, rankErrorForIndex] <- mean(abs(tau_estimate_did-delta_t)^2)
    
      msesRankErrorData['SC', j, rankErrorForIndex] <-  mean(abs(tau_estimate_sc-delta_t)^2)
    
      msesRankErrorData['MC-NNM', j, rankErrorForIndex] <- mean(abs(tau_estimate_mc_nnm-delta_t)^2)
    
      msesRankErrorData['SDID', j, rankErrorForIndex] <- mean(abs(tau_estimate_sdid-delta_t)^2)
    
     msesRankErrorData['LAPIS', j, rankErrorForIndex] <- mean(abs(tau_estimate_lapis-delta_t)^2)
    
      msesRankErrorData['ORACLE', j, rankErrorForIndex] <- mean(abs(tau_estimate_oracle-delta_t)^2)
        
      endTime <- Sys.time()
        
      outMessage <- paste('initial rank error: ', rank_error, '; Iteration: ', j, sep='')
      
      print(outMessage)
      
      print(difftime(endTime, startTime, 'mins'))

    }

  } 

    print(paste("Finished rank error:", rank_error))
}

                                            
meltedRankErrorData <- as_tibble(as.tbl_cube(msesRankErrorData, met="MSE"))
                                            
meltedRankErrorData$Method <- factor(meltedRankErrorData$Method, levels=methodNames)      

                                            
meltedRankErrorData <- meltedRankErrorData  %>% filter(Method !='DID') 
 
aggRankErrorData <- meltedRankErrorData %>% group_by(Method, Rank_error) %>% dplyr::summarize(RMSE = mean(sqrt(MSE)),
                                                                SE = sd(sqrt(MSE))/sqrt(n()))

p_mse_vs_rankError <- (ggplot(aggRankErrorData, aes(x=Rank_error, y=RMSE, col=Method)) + geom_line(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of the Rank of the Initial Rank Error") 
                +xlab("Initial Rank Error") + ylab('RMSE'))
                                            
p_mse_vs_rankError_uncertainty <- (ggplot(meltedRankErrorData, aes(x=Rank_error, y=sqrt(MSE), col=Method)) + geom_smooth(lwd=1.5) + 
                   theme_bw(base_size=20)+ ggtitle("RMSE as a Function of the Rank of the Initial Rank Error") 
                +xlab("Initial Rank Error") + ylab('RMSE'))
# Out:
# [1] "initial rank error: -9; Iteration: 1"
# Time difference of 14.55435 secs
# [1] "initial rank error: -9; Iteration: 2"
# Time difference of 16.96701 secs
# [1] "initial rank error: -9; Iteration: 3"
# Time difference of 18.5849 secs
# [1] "initial rank error: -9; Iteration: 4"
# Time difference of 17.26932 secs
# [1] "initial rank error: -9; Iteration: 5"
# Time difference of 16.35292 secs
# [1] "initial rank error: -9; Iteration: 6"
# Time difference of 21.71025 secs
# [1] "initial rank error: -9; Iteration: 7"
# Time difference of 16.90086 secs
# [1] "initial rank error: -9; Iteration: 8"
# Time difference of 18.21714 secs
# [1] "initial rank error: -9; Iteration: 9"
# Time difference of 18.67524 secs
# [1] "initial rank error: -9; Iteration: 10"
# Time difference of 13.3168 secs
# [1] "initial rank error: -9; Iteration: 11"
# Time difference of 20.26881 secs
# [1] "initial rank error: -9; Iteration: 12"
# Time difference of 21.46379 secs
# [1] "initial rank error: -9; Iteration: 13"
# Time difference of 21.44906 secs
# [1] "initial rank error: -9; Iteration: 14"
# Time difference of 19.80558 secs
# [1] "initial rank error: -9; Iteration: 15"
# Time difference of 14.26407 secs
# [1] "initial rank error: -9; Iteration: 16"
# Time difference of 16.55667 secs
# [1] "initial rank error: -9; Iteration: 17"
# Time difference of 15.7666 secs
# [1] "initial rank error: -9; Iteration: 18"
# Time difference of 17.85804 secs
# [1] "initial rank error: -9; Iteration: 19"
# Time difference of 15.91444 secs
# [1] "initial rank error: -9; Iteration: 20"
# Time difference of 17.90886 secs
# [1] "initial rank error: -9; Iteration: 21"
# Time difference of 16.65956 secs
# [1] "initial rank error: -9; Iteration: 22"
# Time difference of 15.9391 secs
# [1] "initial rank error: -9; Iteration: 23"
# Time difference of 13.01128 secs
# [1] "initial rank error: -9; Iteration: 24"
# Time difference of 16.5242 secs
# [1] "initial rank error: -9; Iteration: 25"
# Time difference of 16.96357 secs
# [1] "initial rank error: -9; Iteration: 26"
# Time difference of 18.02188 secs
# [1] "initial rank error: -9; Iteration: 27"
# Time difference of 17.03597 secs
# [1] "initial rank error: -9; Iteration: 28"
# Time difference of 16.86862 secs
# [1] "initial rank error: -9; Iteration: 29"
# Time difference of 19.44427 secs
# [1] "initial rank error: -9; Iteration: 30"
# Time difference of 19.39231 secs
# [1] "initial rank error: -9; Iteration: 31"
# Time difference of 15.53032 secs
# [1] "initial rank error: -9; Iteration: 32"
# Time difference of 16.65599 secs
# [1] "initial rank error: -9; Iteration: 33"
# Time difference of 17.47623 secs
# [1] "initial rank error: -9; Iteration: 34"
# Time difference of 16.61868 secs
# [1] "initial rank error: -9; Iteration: 35"
# Time difference of 19.86627 secs
# [1] "initial rank error: -9; Iteration: 36"
# Time difference of 15.62217 secs
# [1] "initial rank error: -9; Iteration: 37"
# Time difference of 18.4244 secs
# [1] "initial rank error: -9; Iteration: 38"
# Time difference of 19.77984 secs
# [1] "initial rank error: -9; Iteration: 39"
# Time difference of 11.81685 secs
# [1] "initial rank error: -9; Iteration: 40"
# Time difference of 15.00908 secs
# [1] "initial rank error: -9; Iteration: 41"
# Time difference of 16.6452 secs
# [1] "initial rank error: -9; Iteration: 42"
# Time difference of 15.02141 secs
# [1] "initial rank error: -9; Iteration: 43"
# Time difference of 16.54965 secs
# [1] "initial rank error: -9; Iteration: 44"
# Time difference of 20.92908 secs
# [1] "initial rank error: -9; Iteration: 45"
# Time difference of 16.61837 secs
# [1] "initial rank error: -9; Iteration: 46"
# Time difference of 15.85443 secs
# [1] "initial rank error: -9; Iteration: 47"
# Time difference of 18.62151 secs
# [1] "initial rank error: -9; Iteration: 48"
# Time difference of 12.42531 secs
# [1] "initial rank error: -9; Iteration: 49"
# Time difference of 17.77846 secs
# [1] "initial rank error: -9; Iteration: 50"
# Time difference of 19.81491 secs
# [1] "Finished rank error: -9"
# [1] "initial rank error: -5; Iteration: 1"
# Time difference of 16.55393 secs
# [1] "initial rank error: -5; Iteration: 2"
# Time difference of 21.45335 secs
# [1] "initial rank error: -5; Iteration: 3"
# Time difference of 17.80171 secs
# [1] "initial rank error: -5; Iteration: 4"
# Time difference of 17.92659 secs
# [1] "initial rank error: -5; Iteration: 5"
# Time difference of 14.38748 secs
# [1] "initial rank error: -5; Iteration: 6"
# Time difference of 15.02886 secs
# [1] "initial rank error: -5; Iteration: 7"
# Time difference of 17.36417 secs
# [1] "initial rank error: -5; Iteration: 8"
# Time difference of 13.65411 secs
# [1] "initial rank error: -5; Iteration: 9"
# Time difference of 18.75825 secs
# [1] "initial rank error: -5; Iteration: 10"
# Time difference of 22.59437 secs
# [1] "initial rank error: -5; Iteration: 11"
# Time difference of 18.41147 secs
# [1] "initial rank error: -5; Iteration: 12"
# Time difference of 18.39704 secs
# [1] "initial rank error: -5; Iteration: 13"
# Time difference of 17.4073 secs
# [1] "initial rank error: -5; Iteration: 14"
# Time difference of 20.15179 secs
# [1] "initial rank error: -5; Iteration: 15"
# Time difference of 19.20575 secs
# [1] "initial rank error: -5; Iteration: 16"
# Time difference of 20.58549 secs
# [1] "initial rank error: -5; Iteration: 17"
# Time difference of 14.23192 secs
# [1] "initial rank error: -5; Iteration: 18"
# Time difference of 11.3156 secs
# [1] "initial rank error: -5; Iteration: 19"
# Time difference of 17.09925 secs
# [1] "initial rank error: -5; Iteration: 20"
# Time difference of 17.723 secs
# [1] "initial rank error: -5; Iteration: 21"
# Time difference of 17.3007 secs
# [1] "initial rank error: -5; Iteration: 22"
# Time difference of 17.3584 secs
# [1] "initial rank error: -5; Iteration: 23"
# Time difference of 14.85927 secs
# [1] "initial rank error: -5; Iteration: 24"
# Time difference of 16.16195 secs
# [1] "initial rank error: -5; Iteration: 25"
# Time difference of 10.89004 secs
# [1] "initial rank error: -5; Iteration: 26"
# Time difference of 12.62371 secs
# [1] "initial rank error: -5; Iteration: 27"
# Time difference of 22.51632 secs
# [1] "initial rank error: -5; Iteration: 28"
# Time difference of 16.8753 secs
# [1] "initial rank error: -5; Iteration: 29"
# Time difference of 16.69607 secs
# [1] "initial rank error: -5; Iteration: 30"
# Time difference of 12.94079 secs
# [1] "initial rank error: -5; Iteration: 31"
# Time difference of 14.66079 secs
# [1] "initial rank error: -5; Iteration: 32"
# Time difference of 10.95548 secs
# [1] "initial rank error: -5; Iteration: 33"
# Time difference of 18.67361 secs
# [1] "initial rank error: -5; Iteration: 34"
# Time difference of 16.35 secs
# [1] "initial rank error: -5; Iteration: 35"
# Time difference of 16.93765 secs
# [1] "initial rank error: -5; Iteration: 36"
# Time difference of 17.27095 secs
# [1] "initial rank error: -5; Iteration: 37"
# Time difference of 14.84872 secs
# [1] "initial rank error: -5; Iteration: 38"
# Time difference of 19.9695 secs
# [1] "initial rank error: -5; Iteration: 39"
# Time difference of 13.90152 secs
# [1] "initial rank error: -5; Iteration: 40"
# Time difference of 17.8244 secs
# [1] "initial rank error: -5; Iteration: 41"
# Time difference of 15.53567 secs
# [1] "initial rank error: -5; Iteration: 42"
# Time difference of 16.84499 secs
# [1] "initial rank error: -5; Iteration: 43"
# Time difference of 11.32376 secs
# [1] "initial rank error: -5; Iteration: 44"
# Time difference of 19.82817 secs
# [1] "initial rank error: -5; Iteration: 45"
# Time difference of 16.59054 secs
# [1] "initial rank error: -5; Iteration: 46"
# Time difference of 14.39203 secs
# [1] "initial rank error: -5; Iteration: 47"
# Time difference of 15.14963 secs
# [1] "initial rank error: -5; Iteration: 48"
# Time difference of 17.63258 secs
# [1] "initial rank error: -5; Iteration: 49"
# Time difference of 11.97722 secs
# [1] "initial rank error: -5; Iteration: 50"
# Time difference of 13.93322 secs
# [1] "Finished rank error: -5"
# [1] "initial rank error: 1; Iteration: 1"
# Time difference of 19.76402 secs
# [1] "initial rank error: 1; Iteration: 2"
# Time difference of 21.01799 secs
# [1] "initial rank error: 1; Iteration: 3"
# Time difference of 23.59055 secs
# [1] "initial rank error: 1; Iteration: 4"
# Time difference of 23.94418 secs
# [1] "initial rank error: 1; Iteration: 5"
# Time difference of 18.6199 secs
# [1] "initial rank error: 1; Iteration: 6"
# Time difference of 15.97117 secs
# [1] "initial rank error: 1; Iteration: 7"
# Time difference of 22.87448 secs
# [1] "initial rank error: 1; Iteration: 8"
# Time difference of 23.53004 secs
# [1] "initial rank error: 1; Iteration: 9"
# Time difference of 22.45551 secs
# [1] "initial rank error: 1; Iteration: 10"
# Time difference of 24.57954 secs
# [1] "initial rank error: 1; Iteration: 11"
# Time difference of 21.99193 secs
# [1] "initial rank error: 1; Iteration: 12"
# Time difference of 21.88743 secs
# [1] "initial rank error: 1; Iteration: 13"
# Time difference of 21.34383 secs
# [1] "initial rank error: 1; Iteration: 14"
# Time difference of 20.53808 secs
# [1] "initial rank error: 1; Iteration: 15"
# Time difference of 18.44803 secs
# [1] "initial rank error: 1; Iteration: 16"
# Time difference of 22.06426 secs
# [1] "initial rank error: 1; Iteration: 17"
# Time difference of 20.91009 secs
# [1] "initial rank error: 1; Iteration: 18"
# Time difference of 22.19712 secs
# [1] "initial rank error: 1; Iteration: 19"
# Time difference of 23.81489 secs
# [1] "initial rank error: 1; Iteration: 20"
# Time difference of 24.58782 secs
# [1] "initial rank error: 1; Iteration: 21"
# Time difference of 24.62523 secs
# [1] "initial rank error: 1; Iteration: 22"
# Time difference of 21.84641 secs
# [1] "initial rank error: 1; Iteration: 23"
# Time difference of 25.82574 secs
# [1] "initial rank error: 1; Iteration: 24"
# Time difference of 18.21078 secs
# [1] "initial rank error: 1; Iteration: 25"
# Time difference of 23.21219 secs
# [1] "initial rank error: 1; Iteration: 26"
# Time difference of 21.20898 secs
# [1] "initial rank error: 1; Iteration: 27"
# Time difference of 19.82696 secs
# [1] "initial rank error: 1; Iteration: 28"
# Time difference of 18.70951 secs
# [1] "initial rank error: 1; Iteration: 29"
# Time difference of 25.45758 secs
# [1] "initial rank error: 1; Iteration: 30"
# Time difference of 21.85958 secs
# [1] "initial rank error: 1; Iteration: 31"
# Time difference of 22.05176 secs
# [1] "initial rank error: 1; Iteration: 32"
# Time difference of 18.15113 secs
# [1] "initial rank error: 1; Iteration: 33"
# Time difference of 19.37157 secs
# [1] "initial rank error: 1; Iteration: 34"
# Time difference of 21.54394 secs
# [1] "initial rank error: 1; Iteration: 35"
# Time difference of 19.91559 secs
# [1] "initial rank error: 1; Iteration: 36"
# Time difference of 22.84545 secs
# [1] "initial rank error: 1; Iteration: 37"
# Time difference of 20.12897 secs
# [1] "initial rank error: 1; Iteration: 38"
# Time difference of 19.02832 secs
# [1] "initial rank error: 1; Iteration: 39"
# Time difference of 16.72966 secs
# [1] "initial rank error: 1; Iteration: 40"
# Time difference of 24.56846 secs
# [1] "initial rank error: 1; Iteration: 41"
# Time difference of 18.61711 secs
# [1] "initial rank error: 1; Iteration: 42"
# Time difference of 22.90751 secs
# [1] "initial rank error: 1; Iteration: 43"
# Time difference of 26.34501 secs
# [1] "initial rank error: 1; Iteration: 44"
# Time difference of 22.52684 secs
# [1] "initial rank error: 1; Iteration: 45"
# Time difference of 20.78235 secs
# [1] "initial rank error: 1; Iteration: 46"
# Time difference of 21.76911 secs
# [1] "initial rank error: 1; Iteration: 47"
# Time difference of 17.42767 secs
# [1] "initial rank error: 1; Iteration: 48"
# Time difference of 19.46044 secs
# [1] "initial rank error: 1; Iteration: 49"
# Time difference of 16.8163 secs
# [1] "initial rank error: 1; Iteration: 50"
# Time difference of 17.51483 secs
# [1] "Finished rank error: 1"
# [1] "initial rank error: 3; Iteration: 1"
# Time difference of 25.00999 secs
# [1] "initial rank error: 3; Iteration: 2"
# Time difference of 25.14657 secs
# [1] "initial rank error: 3; Iteration: 3"
# Time difference of 26.32924 secs
# [1] "initial rank error: 3; Iteration: 4"
# Time difference of 27.90587 secs
# [1] "initial rank error: 3; Iteration: 5"
# Time difference of 21.76016 secs
# [1] "initial rank error: 3; Iteration: 6"
# Time difference of 20.22043 secs
# [1] "initial rank error: 3; Iteration: 7"
# Time difference of 26.79409 secs
# [1] "initial rank error: 3; Iteration: 8"
# Time difference of 21.76062 secs
# [1] "initial rank error: 3; Iteration: 9"
# Time difference of 21.74946 secs
# [1] "initial rank error: 3; Iteration: 10"
# Time difference of 19.26497 secs
# [1] "initial rank error: 3; Iteration: 11"
# Time difference of 27.12636 secs
# [1] "initial rank error: 3; Iteration: 12"
# Time difference of 26.51367 secs
# [1] "initial rank error: 3; Iteration: 13"
# Time difference of 24.22147 secs
# [1] "initial rank error: 3; Iteration: 14"
# Time difference of 29.03739 secs
# [1] "initial rank error: 3; Iteration: 15"
# Time difference of 24.79964 secs
# [1] "initial rank error: 3; Iteration: 16"
# Time difference of 26.24574 secs
# [1] "initial rank error: 3; Iteration: 17"
# Time difference of 23.0548 secs
# [1] "initial rank error: 3; Iteration: 18"
# Time difference of 26.70612 secs
# [1] "initial rank error: 3; Iteration: 19"
# Time difference of 21.85063 secs
# [1] "initial rank error: 3; Iteration: 20"
# Time difference of 24.64734 secs
# [1] "initial rank error: 3; Iteration: 21"
# Time difference of 25.50529 secs
# [1] "initial rank error: 3; Iteration: 22"
# Time difference of 28.72195 secs
# [1] "initial rank error: 3; Iteration: 23"
# Time difference of 25.72749 secs
# [1] "initial rank error: 3; Iteration: 24"
# Time difference of 25.47239 secs
# [1] "initial rank error: 3; Iteration: 25"
# Time difference of 25.82025 secs
# [1] "initial rank error: 3; Iteration: 26"
# Time difference of 27.18366 secs
# [1] "initial rank error: 3; Iteration: 27"
# Time difference of 26.96263 secs
# [1] "initial rank error: 3; Iteration: 28"
# Time difference of 27.01722 secs
# [1] "initial rank error: 3; Iteration: 29"
# Time difference of 24.93329 secs
# [1] "initial rank error: 3; Iteration: 30"
# Time difference of 26.29132 secs
# [1] "initial rank error: 3; Iteration: 31"
# Time difference of 26.44539 secs
# [1] "initial rank error: 3; Iteration: 32"
# Time difference of 25.6421 secs
# [1] "initial rank error: 3; Iteration: 33"
# Time difference of 27.46226 secs
# [1] "initial rank error: 3; Iteration: 34"
# Time difference of 23.96067 secs
# [1] "initial rank error: 3; Iteration: 35"
# Time difference of 22.76341 secs
# [1] "initial rank error: 3; Iteration: 36"
# Time difference of 25.23595 secs
# [1] "initial rank error: 3; Iteration: 37"
# Time difference of 20.54622 secs
# [1] "initial rank error: 3; Iteration: 38"
# Time difference of 23.53961 secs
# [1] "initial rank error: 3; Iteration: 39"
# Time difference of 27.02075 secs
# [1] "initial rank error: 3; Iteration: 40"
# Time difference of 22.35966 secs
# [1] "initial rank error: 3; Iteration: 41"
# Time difference of 24.40606 secs
# [1] "initial rank error: 3; Iteration: 42"
# Time difference of 29.61618 secs
# [1] "initial rank error: 3; Iteration: 43"
# Time difference of 24.47322 secs
# [1] "initial rank error: 3; Iteration: 44"
# Time difference of 25.34697 secs
# [1] "initial rank error: 3; Iteration: 45"
# Time difference of 24.34437 secs
# [1] "initial rank error: 3; Iteration: 46"
# Time difference of 23.15199 secs
# [1] "initial rank error: 3; Iteration: 47"
# Time difference of 26.57427 secs
# [1] "initial rank error: 3; Iteration: 48"
# Time difference of 26.39293 secs
# [1] "initial rank error: 3; Iteration: 49"
# Time difference of 25.40871 secs
# [1] "initial rank error: 3; Iteration: 50"
# Time difference of 29.71065 secs
# [1] "Finished rank error: 3"
# [1] "initial rank error: 7; Iteration: 1"
# Time difference of 32.91035 secs
# [1] "initial rank error: 7; Iteration: 2"
# Time difference of 36.02663 secs
# [1] "initial rank error: 7; Iteration: 3"
# Time difference of 34.45261 secs
# [1] "initial rank error: 7; Iteration: 4"
# Time difference of 32.21745 secs
# [1] "initial rank error: 7; Iteration: 5"
# Time difference of 34.30226 secs
# [1] "initial rank error: 7; Iteration: 6"
# Time difference of 34.8728 secs
# [1] "initial rank error: 7; Iteration: 7"
# Time difference of 37.81414 secs
# [1] "initial rank error: 7; Iteration: 8"
# Time difference of 35.33705 secs
# [1] "initial rank error: 7; Iteration: 9"
# Time difference of 30.16437 secs
# [1] "initial rank error: 7; Iteration: 10"
# Time difference of 34.94926 secs
# [1] "initial rank error: 7; Iteration: 11"
# Time difference of 36.3302 secs
# [1] "initial rank error: 7; Iteration: 12"
# Time difference of 39.603 secs
# [1] "initial rank error: 7; Iteration: 13"
# Time difference of 32.97646 secs
# [1] "initial rank error: 7; Iteration: 14"
# Time difference of 36.92741 secs
# [1] "initial rank error: 7; Iteration: 15"
# Time difference of 30.64199 secs
# [1] "initial rank error: 7; Iteration: 16"
# Time difference of 35.83707 secs
# [1] "initial rank error: 7; Iteration: 17"
# Time difference of 33.22158 secs
# [1] "initial rank error: 7; Iteration: 18"
# Time difference of 35.65582 secs
# [1] "initial rank error: 7; Iteration: 19"
# Time difference of 30.69969 secs
# [1] "initial rank error: 7; Iteration: 20"
# Time difference of 35.81731 secs
# [1] "initial rank error: 7; Iteration: 21"
# Time difference of 33.20765 secs
# [1] "initial rank error: 7; Iteration: 22"
# Time difference of 36.70512 secs
# [1] "initial rank error: 7; Iteration: 23"
# Time difference of 27.09806 secs
# [1] "initial rank error: 7; Iteration: 24"
# Time difference of 34.52323 secs
# [1] "initial rank error: 7; Iteration: 25"
# Time difference of 34.1175 secs
# [1] "initial rank error: 7; Iteration: 26"
# Time difference of 32.73589 secs
# [1] "initial rank error: 7; Iteration: 27"
# Time difference of 35.0071 secs
# [1] "initial rank error: 7; Iteration: 28"
# Time difference of 35.46885 secs
# [1] "initial rank error: 7; Iteration: 29"
# Time difference of 33.2165 secs
# [1] "initial rank error: 7; Iteration: 30"
# Time difference of 36.42034 secs
# [1] "initial rank error: 7; Iteration: 31"
# Time difference of 33.91038 secs
# [1] "initial rank error: 7; Iteration: 32"
# Time difference of 34.4474 secs
# [1] "initial rank error: 7; Iteration: 33"
# Time difference of 31.02348 secs
# [1] "initial rank error: 7; Iteration: 34"
# Time difference of 37.37075 secs
# [1] "initial rank error: 7; Iteration: 35"
# Time difference of 35.35869 secs
# [1] "initial rank error: 7; Iteration: 36"
# Time difference of 36.82748 secs
# [1] "initial rank error: 7; Iteration: 37"
# Time difference of 31.18747 secs
# [1] "initial rank error: 7; Iteration: 38"
# Time difference of 30.40845 secs
# [1] "initial rank error: 7; Iteration: 39"
# Time difference of 31.27042 secs
# [1] "initial rank error: 7; Iteration: 40"
# Time difference of 35.59876 secs
# [1] "initial rank error: 7; Iteration: 41"
# Time difference of 33.96977 secs
# [1] "initial rank error: 7; Iteration: 42"
# Time difference of 33.18669 secs
# [1] "initial rank error: 7; Iteration: 43"
# Time difference of 37.48644 secs
# [1] "initial rank error: 7; Iteration: 44"
# Time difference of 35.18146 secs
# [1] "initial rank error: 7; Iteration: 45"
# Time difference of 38.83077 secs
# [1] "initial rank error: 7; Iteration: 46"
# Time difference of 32.59414 secs
# [1] "initial rank error: 7; Iteration: 47"
# Time difference of 34.9834 secs
# [1] "initial rank error: 7; Iteration: 48"
# Time difference of 31.75002 secs
# [1] "initial rank error: 7; Iteration: 49"
# Time difference of 38.57103 secs
# [1] "initial rank error: 7; Iteration: 50"
# Time difference of 38.72989 secs
# [1] "Finished rank error: 7"

# %%
rankErrorRMSEDataForLatex <- aggRankErrorData %>% mutate(
    `RMSE (SE)` = paste(round(RMSE, 3), ' (', round(SE, 3), ')', sep='')) 

rankErrorRMSEDataForLatex <- rankErrorRMSEDataForLatex[c('Method', 'RMSE (SE)', 'Rank_error')]


rankErrorRMSEDataForLatex <-spread(rankErrorRMSEDataForLatex, key=Rank_error, value=`RMSE (SE)`)


rankErrorRMSEDataForLatex <- knitr::kable(rankErrorRMSEDataForLatex, 'latex')

# %%
server_name <- Sys.info()['nodename']                                        
                                            
                                            
sim_error_date_directory <- paste("../reports/", server_name,'/',
design, "_simulations","/" ,c('unbalanced', 'balanced')[balanced+1], '/' , Sys.Date(), "_simulations", sep='')

if (!dir.exists(sim_error_date_directory)){
  
  dir.create(path=sim_error_date_directory, recursive = TRUE)
  
}                                            
                                            
                                            
runsAlreadyDone <- length(list.files(sim_error_date_directory))                                            
                                            
                                            
                        
                                            
full_output_directory <- paste(sim_error_date_directory, paste('run', runsAlreadyDone+1, sep='_'),sep='/')

image_directory <- paste(full_output_directory, "/simulation_plots", sep="")

table_directory <- paste(full_output_directory, "/simulation_tables", sep="")

if (!dir.exists(image_directory)){

    dir.create(image_directory, recursive=TRUE)
  
}          


if (!dir.exists(table_directory)){

    dir.create(table_directory, recursive=TRUE)
  
}

# %%
image_directory
# Out:
# [1] "../reports/Compy386/simultaneous_adoption_simulations/balanced/2021-01-31_simulations/run_1/simulation_plots"

# %%
if (exists("effect_plot")){

ggsave(paste(image_directory,'/effect_size_plot.pdf' , sep=''), effect_plot,
       width=11, height=8.5)
}

if (exists("tableForPresenting")){
                                            
    fileConn<-file(makeFilename(table_directory, 
                                fileName='fixed_parameter_error_table.txt'))
    writeLines(tableForPresenting , fileConn)
    close(fileConn)    

    }


 
if (exists("p_mse_vs_N0")){

    ggsave(paste(image_directory,'/varied_N0.pdf' , sep=''), p_mse_vs_N0, width=11, height=8.5)

    ggsave(paste(image_directory,'/varied_N0_with_uncertainty.pdf' , sep=''), p_mse_vs_N0_uncertainty, 
           width=11, height=8.5)    
    
    fileConn<-file(makeFilename(table_directory, 
                                fileName='N0_rmse_table.txt'))
    writeLines(N0RMSEDataForLatex , fileConn)
    close(fileConn) 

}
                                            
                                                                  
if (exists("p_mse_vs_rho")){
  
    ggsave(paste(image_directory,'/varied_rho.pdf' , sep=''), p_mse_vs_rho,
           width=11, height=8.5)

    ggsave(paste(image_directory,'/varied_rho_with_uncertainty.pdf' , sep=''), p_mse_vs_rho_uncertainty,
           width=11, height=8.5)     
    
    
    fileConn<-file(makeFilename(table_directory, 
                                fileName='rho_rmse_table.txt'))
    writeLines(rhoRMSEDataForLatex , fileConn)
    close(fileConn)  
     
     
}


if (exists("p_mse_vs_tau")){

    ggsave(paste(image_directory,'/varied_tau.pdf' , sep=''), p_mse_vs_tau,
           width=11, height=8.5)

    ggsave(paste(image_directory,'/varied_tau_with_uncertainty.pdf' , sep=''), p_mse_vs_tau_uncertainty,
           width=11, height=8.5)
    
    
    fileConn<-file(makeFilename(table_directory, 
                                fileName='tau_rmse_table.txt'))
    writeLines(tauRMSEDataForLatex , fileConn)
    close(fileConn)  
} 

if (exists("p_mse_vs_rank")){

    ggsave(paste(image_directory,'/varied_rank.pdf' , sep=''), p_mse_vs_rank, width=11, height=8.5)

    ggsave(paste(image_directory,'/varied_rank_with_uncertainty.pdf' , sep=''), 
           p_mse_vs_rank_uncertainty, width=11, height=8.5)
    
    fileConn<-file(makeFilename(table_directory, 
                                fileName='rank_rmse_table.txt'))
    writeLines(rankRMSEDataForLatex , fileConn)
    close(fileConn) 
  
}   



if (exists("p_mse_vs_rankError")){

    ggsave(paste(image_directory,'/varied_rank_error.pdf' , sep=''), p_mse_vs_rankError, width=11, height=8.5)

    ggsave(paste(image_directory,'/varied_rank_error_with_uncertainty.pdf' , sep=''), 
           p_mse_vs_rankError_uncertainty, width=11, height=8.5)    
    
    
    fileConn<-file(makeFilename(table_directory, 
                                fileName='rank_error_rmse_table.txt'))
    writeLines(rankErrorRMSEDataForLatex , fileConn)
    close(fileConn) 
    
    
}




                                            
                                           
write.csv(params, file=paste(full_output_directory,
                             "simulation_parameters.csv", sep="/"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 11”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 10”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  6.1125e-17”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 11”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 10”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  6.1125e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 11”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 10”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  6.1125e-17”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 11”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 10”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  6.1125e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 11”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 10”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  6.1125e-17”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 11”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 10”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  6.1125e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 11”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 10”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  6.1125e-17”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 11”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 10”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  6.1125e-17”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 11”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 10”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  6.1125e-17”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 11”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 10”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  6.1125e-17”
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 6”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.7487e-16”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 1”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 6”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  2.7487e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 6”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.7487e-16”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 1”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 6”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  2.7487e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 6”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.7487e-16”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 1”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 6”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  2.7487e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 6”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.7487e-16”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 1”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 6”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  2.7487e-16”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 6”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  2.7487e-16”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 1”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 6”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “reciprocal condition number  2.7487e-16”

# %%
# write.table(L, file="fixed_L.txt", row.names=FALSE, col.names=FALSE)

stopCluster(cl)
